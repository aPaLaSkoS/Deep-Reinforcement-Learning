# %% [markdown]
# # Imports + Installs

# %%
# !pip install "gym[atari, accept-rom-license]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym[accept-rom-license,atari] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (0.0.8)
# Collecting ale-py~=0.7.5 (from gym[accept-rom-license,atari])
#   Downloading ale_py-0.7.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 36.7 MB/s eta 0:00:00
# Collecting autorom[accept-rom-license]~=0.4.2 (from gym[accept-rom-license,atari])
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.7.5->gym[accept-rom-license,atari]) (5.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (8.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (4.65.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 44.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (3.4)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=4abf9e6188d6aa8d3f6ae2a38f84255cd2cff575b8a0607a5e875250cb2acec9
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: ale-py, AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.7.5 autorom-0.4.2

# %%
import gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import collections
import cv2
import os
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import warnings
from google.colab import files
warnings.filterwarnings("ignore")

# %% [markdown]
# # Classes + Helpers

# %% [markdown]
# ## Environment

# %%
class RepeatActionAndMaxFrame(gym.Wrapper):
  def __init__(self, env=None, repeat=4, clip_rewards=False, no_ops=0, fire_first=False):
    super(RepeatActionAndMaxFrame, self).__init__(env)
    self.repeat = repeat
    self.shape = env.observation_space.low.shape
    self.frame_buffer = np.zeros_like((2, self.shape))
    self.clip_rewards = clip_rewards 
    self.no_ops = no_ops
    self.fire_first = fire_first
  
  def step(self, action):
    total_reward = 0.0
    done = False
    for i in range(self.repeat):
      obs, reward, done, info = self.env.step(action)
      if self.clip_rewards:
        reward = np.clip(np.array([reward]), -1, 1)[0]
      total_reward += reward
      idx = i % 2
      self.frame_buffer[idx] = obs
      if done:
        break

    max_frame = np.maximum(self.frame_buffer[0], self.frame_buffer[1])
    return max_frame, total_reward, done, info
  
  def reset(self):
    obs = self.env.reset()
    no_ops = np.random.randint(self.no_ops) + 1 if self.no_ops > 0 else 0
    for _ in range(no_ops):
      _, _, done, _ = self.env.step(0)
      if done:
        self.env.reset()
    if self.fire_first:
      assert self.env.unwrapped.get_action_meanings()[1] == 'FIRE'
      obs, _, _, _ = self.env.step(1)

    self.frame_buffer = np.zeros_like((2, self.shape))
    self.frame_buffer[0] = obs
    return obs


class PreprocessFrame(gym.ObservationWrapper):
  def __init__(self, shape, env=None):
    super(PreprocessFrame, self).__init__(env)
    self.shape = (shape[2], shape[0], shape[1])
    self.observation_space = gym.spaces.Box(low=0.0, high=1.0,
                                            shape=self.shape,
                                            dtype=np.float32)
  
  def observation(self, obs):
    new_frame = cv2.cvtColor(obs, cv2.COLOR_BGR2GRAY)
    resized_screen = cv2.resize(new_frame, 
                                self.shape[1:],
                                interpolation=cv2.INTER_AREA)
    new_obs = np.array(resized_screen, dtype=np.float16).reshape(self.shape)
    new_obs /= 255.0

    return new_obs


class StackFrames(gym.ObservationWrapper):
  def __init__(self, env, repeat):
    super(StackFrames, self).__init__(env)
    self.observation_space = gym.spaces.Box(
        env.observation_space.low.repeat(repeat, axis=0),
        env.observation_space.high.repeat(repeat, axis=0)
    )
    self.stack = collections.deque(maxlen=repeat)

  def reset(self):
    self.stack.clear()
    observation = self.env.reset()
    for _ in range(self.stack.maxlen):
      self.stack.append(observation)
    
    return np.array(self.stack).reshape(self.observation_space.low.shape)
  
  def observation(self, observation):
    self.stack.append(observation)
    return np.array(self.stack).reshape(self.observation_space.low.shape)


def make_env(env_name, shape=(84, 84, 1), repeat=4, clip_rewards=False, no_ops=0, fire_first=False):
  env = gym.make(env_name)
  env = RepeatActionAndMaxFrame(env, repeat, clip_rewards, no_ops, fire_first)
  env = PreprocessFrame(shape, env)
  env = StackFrames(env, repeat)
  return env

# %% [markdown]
# ## Agent

# %%
class ReplayBuffer():
  def __init__(self, max_size, input_shape, n_actions):
    self.mem_size = max_size
    self.mem_counter = 0
    self.state_memory = np.zeros(
        (self.mem_size, *input_shape),
        dtype=np.float32
    )
    self.new_state_memory = np.zeros(
        (self.mem_size, *input_shape),
        dtype=np.float32
    )
    self.action_memory = np.zeros(self.mem_size, dtype=np.int64)
    self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
    self.terminal_memory = np.zeros(self.mem_size, dtype=np.uint8)
  
  def store_transition(self, state, action, reward, state_, done):
    index = self.mem_counter % self.mem_size
    self.state_memory[index] = state
    self.action_memory[index] = action
    self.reward_memory[index] = reward
    self.new_state_memory[index] = state_
    self.terminal_memory[index] = done
    self.mem_counter += 1
  
  def sample_buffer(self, batch_size):
    max_mem = min(self.mem_counter, self.mem_size)
    batch = np.random.choice(max_mem, batch_size, replace=True)
    states = self.state_memory[batch]
    actions = self.action_memory[batch]
    rewards = self.reward_memory[batch]
    states_ = self.new_state_memory[batch]
    dones = self.terminal_memory[batch]

    return states, actions, rewards, states_, dones


class DuelingDeepQNetwork(nn.Module):
  def __init__(self, lr, n_actions, name, input_dims, chkpt_dir):
    super(DuelingDeepQNetwork, self).__init__()
    self.checkpoint_dir = chkpt_dir
    self.checkpoint_file = os.path.join(self.checkpoint_dir, name)
    if not os.path.exists(self.checkpoint_dir):
      os.makedirs(self.checkpoint_dir)

    self.conv1 = nn.Conv2d(input_dims[0], 32, 8, stride=4)
    self.conv2 = nn.Conv2d(32, 64, 4, stride=2)
    self.conv3 = nn.Conv2d(64, 64, 3, stride=1)

    fc_input_dims = self.calculate_conv_output_dims(input_dims)
    
    self.fc1 = nn.Linear(fc_input_dims, 512)
    self.V = nn.Linear(512, 1)
    self.A = nn.Linear(512, n_actions)

    self.optimizer = optim.RMSprop(self.parameters(), lr=lr)
    self.loss = nn.MSELoss()
    self.device = T.device('cuda' if T.cuda.is_available() else 'cpu')
    self.to(self.device)

  def calculate_conv_output_dims(self, input_dims):
    state = T.zeros(1, *input_dims)
    dims = self.conv1(state)
    dims = self.conv2(dims)
    dims = self.conv3(dims)
    return int(np.prod(dims.size()))

  def forward(self, state):
    state = F.relu(self.conv1(state))
    state = F.relu(self.conv2(state))
    state = F.relu(self.conv3(state))
    # conv3 shape is: batch_size x n_filters x H x W
    state = state.view(state.size()[0], -1)
    state = F.relu(self.fc1(state))
    V = self.V(state)
    A = self.A(state)

    return V, A

  def save_checkpoint(self):
    print('... saving checkpoint ...')
    T.save(self.state_dict(), self.checkpoint_file)
  
  def load_checkpoint(self):
    print('... loading checkpoint ...')
    self.load_state_dict(T.load(self.checkpoint_file))


class DuelingDDQNAgent():
  def __init__(self, gamma, epsilon, lr, n_actions, input_dims,
               mem_size, batch_size, eps_min=0.01, eps_dec=5e-7, 
               replace=1000, algo=None, env_name=None, chkpt_dir='tmp/dqn'):
    self.gamma = gamma
    self.epsilon = epsilon
    self.lr = lr
    self.n_actions = n_actions
    self.input_dims = input_dims
    self.batch_size = batch_size
    self.eps_min = eps_min
    self.eps_dec = eps_dec
    self.replace_target_counter = replace
    self.algo = algo
    self.env_name = env_name
    self.chkpt_dir = chkpt_dir
    self.action_space = [i for i in range(self.n_actions)]
    self.learn_step_counter = 0

    self.memory = ReplayBuffer(mem_size, input_dims, n_actions)

    self.Q_eval = DuelingDeepQNetwork(self.lr, self.n_actions,
                                      input_dims=self.input_dims,
                                      name=self.env_name + '_' + self.algo + '_Q_eval.pth',
                                      chkpt_dir=self.chkpt_dir)

    self.Q_next = DuelingDeepQNetwork(self.lr, self.n_actions,
                                      input_dims=self.input_dims,
                                      name=self.env_name + '_' + self.algo + '_Q_next.pth',
                                      chkpt_dir=self.chkpt_dir)   
  
  def choose_action(self, observation):
    if np.random.random() > self.epsilon:
      state = T.tensor([observation], dtype=T.float).to(self.Q_eval.device)
      _, advantage = self.Q_eval.forward(state)
      action = T.argmax(advantage).item()
    else:
      action = np.random.choice(self.action_space)
    return action
  
  def store_transition(self, state, action, reward, state_, done):
    self.memory.store_transition(state, action, reward, state_, done)
  
  def sample_memory(self):
    state, action, reward, new_state, done = self.memory.sample_buffer(self.batch_size)
    states = T.tensor(state).to(self.Q_eval.device)
    actions = T.tensor(action).to(self.Q_eval.device)
    rewards = T.tensor(reward).to(self.Q_eval.device)
    states_ = T.tensor(new_state).to(self.Q_eval.device)
    dones = T.tensor(done).to(self.Q_eval.device)

    return states, actions, rewards, states_, dones
  
  def replace_target_network(self):
    if self.learn_step_counter % self.replace_target_counter == 0:
      self.Q_next.load_state_dict(self.Q_eval.state_dict())
  
  def decrement_epsilon(self):
    self.epsilon = self.epsilon - self.eps_dec if self.epsilon > self.eps_min else self.eps_min
  
  def save_models(self):
    self.Q_eval.save_checkpoint()
    self.Q_next.save_checkpoint()

  def load_models(self):
    self.Q_eval.load_checkpoint()
    self.Q_next.load_checkpoint()
  
  def learn(self):
    if self.memory.mem_counter < self.batch_size:
      return 
    
    self.Q_eval.optimizer.zero_grad()

    self.replace_target_network()
    states, actions, rewards, states_, dones = self.sample_memory()

    indices = np.arange(self.batch_size)

    # ================== CHANGES START HERE ... =====================
    Vs, As = self.Q_eval.forward(states)
    Vs_, As_  = self.Q_next.forward(states_)

    Vs_eval, As_eval = self.Q_eval.forward(states_)

    Q_pred = T.add(Vs, (As - As.mean(dim=1, keepdim=True)))[indices, actions]
    Q_next = T.add(Vs_, (As_ - As_.mean(dim=1, keepdim=True)))

    Q_eval =  T.add(Vs_eval, (As_eval - As_eval.mean(dim=1, keepdim=True)))

    max_actions = T.argmax(Q_eval, dim=1)
    # print(max_actions)
    
    # where the episodes are reach a terminal state (done=1),
    # there target must be equal to r
    Q_next[dones] = 0.0
    Q_target = rewards + self.gamma * Q_next[indices, max_actions]
    # ================== CHANGES END HERE ... =======================

    loss = self.Q_eval.loss(Q_target, Q_pred).to(self.Q_eval.device)
    loss.backward()
    self.Q_eval.optimizer.step()
    self.learn_step_counter += 1

    self.decrement_epsilon()

# %% [markdown]
# ## Other

# %%
def  plot_learning_curve(x, scores, epsilons, lines=None):
  fig = plt.figure(figsize=(30, 10))
  ax = fig.add_subplot(111, label='1')
  ax2 = fig.add_subplot(111, label='2', frame_on=False)

  ax.plot(x, epsilons, color='C0')
  ax.set_xlabel("Training steps", color="C0")
  ax.set_ylabel("Epsilon", color="C0")
  ax.tick_params(axis='x', colors="C0")
  ax.tick_params(axis='y', colors='C0')

  N = len(scores)
  running_avg = np.empty(N)
  for t in range(N):
    running_avg[t] = np.mean(scores[max(0, t-20):(t+1)])
  
  ax2.scatter(x, running_avg, color="C1")
  ax2.axes.get_xaxis().set_visible(False)
  ax2.yaxis.tick_right()
  ax2.set_ylabel('Score', color="C1")
  ax2.yaxis.set_label_position('right')
  ax2.tick_params(axis='y', colors="C1")

  if lines is not None:
    for line in lines:
      plt.axvline(x=line)
  
  # plt.savefig(filename)

# %% [markdown]
# # MAIN

# %%
# !rm -rf './models'
env = make_env('PongNoFrameskip-v4')

best_score = -np.inf
load_checkpoint = False
n_games = 500

agent = DuelingDDQNAgent(gamma=0.99, epsilon=1.0, lr=1e-4,
                          input_dims=(env.observation_space.shape),
                          n_actions=env.action_space.n, mem_size=20000, 
                          eps_min=0.1, batch_size=32, replace=1000, 
                          eps_dec=1e-5, chkpt_dir='models/', 
                          algo='DuelingDDQNAgent', env_name='PongNoFrameskip-v4')

if load_checkpoint:
  agent.load_models()

# file_name = agent.algo +'_' + agent.env_name + '_lr' + str(agent.lr) + '_' + str(n_games) + '_games'
# figure_file = 'plots/' + file_name + '.png'

n_steps = 0
scores, eps_history, steps_array = [], [], []

for i in range(n_games):
  print(f"\nGame {i+1}")
  done = False
  score = 0
  observation = env.reset()

  while not done:
    action = agent.choose_action(observation)
    observation_, reward, done, info = env.step(action)
    score += reward

    if not load_checkpoint:
      agent.store_transition(observation, action, reward, observation_, int(done))
      agent.learn()
    
    observation = observation_
    n_steps += 1

  scores.append(score)
  steps_array.append(n_steps)

  avg_score = np.mean(scores[-100:])
  print(f"Episode: {i}, score: {score}, avg_score: {avg_score}, best_score: {best_score}, epsilon: {agent.epsilon}")

  if avg_score > best_score:
    if not load_checkpoint:
      agent.save_models()
    best_score = avg_score
  
  eps_history.append(agent.epsilon)

plot_learning_curve(steps_array, scores, eps_history)

df = pd.DataFrame(
    {
        'steps_array': steps_array, 
        'scores': scores, 
        'eps_history': eps_history
    }
)

filename = 'Atari_DuelingDoubleDQL_results.csv' 
df.to_csv(filename)
files.download(filename)
# Out:
# Game 1
# Episode: 0, score: -21.0, avg_score: -21.0, best_score: -inf, epsilon: 0.9917600000000375
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 2
# Episode: 1, score: -20.0, avg_score: -20.5, best_score: -21.0, epsilon: 0.9816600000000835
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 3
# Episode: 2, score: -19.0, avg_score: -20.0, best_score: -20.5, epsilon: 0.9721700000001267
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 4
# Episode: 3, score: -20.0, avg_score: -20.0, best_score: -20.0, epsilon: 0.9622400000001718
#
# Game 5
# Episode: 4, score: -21.0, avg_score: -20.2, best_score: -20.0, epsilon: 0.9538100000002102
#
# Game 6
# Episode: 5, score: -21.0, avg_score: -20.333333333333332, best_score: -20.0, epsilon: 0.945280000000249
#
# Game 7
# Episode: 6, score: -20.0, avg_score: -20.285714285714285, best_score: -20.0, epsilon: 0.9356800000002927
#
# Game 8
# Episode: 7, score: -21.0, avg_score: -20.375, best_score: -20.0, epsilon: 0.9277500000003288
#
# Game 9
# Episode: 8, score: -20.0, avg_score: -20.333333333333332, best_score: -20.0, epsilon: 0.9175500000003752
#
# Game 10
# Episode: 9, score: -21.0, avg_score: -20.4, best_score: -20.0, epsilon: 0.9081300000004181
#
# Game 11
# Episode: 10, score: -19.0, avg_score: -20.272727272727273, best_score: -20.0, epsilon: 0.8989700000004598
#
# Game 12
# Episode: 11, score: -21.0, avg_score: -20.333333333333332, best_score: -20.0, epsilon: 0.8899300000005009
#
# Game 13
# Episode: 12, score: -21.0, avg_score: -20.384615384615383, best_score: -20.0, epsilon: 0.8802800000005448
#
# Game 14
# Episode: 13, score: -21.0, avg_score: -20.428571428571427, best_score: -20.0, epsilon: 0.871230000000586
#
# Game 15
# Episode: 14, score: -21.0, avg_score: -20.466666666666665, best_score: -20.0, epsilon: 0.8622700000006268
#
# Game 16
# Episode: 15, score: -21.0, avg_score: -20.5, best_score: -20.0, epsilon: 0.8522400000006725
#
# Game 17
# Episode: 16, score: -19.0, avg_score: -20.41176470588235, best_score: -20.0, epsilon: 0.8417200000007203
#
# Game 18
# Episode: 17, score: -18.0, avg_score: -20.27777777777778, best_score: -20.0, epsilon: 0.8299100000007741
#
# Game 19
# Episode: 18, score: -19.0, avg_score: -20.210526315789473, best_score: -20.0, epsilon: 0.8196300000008209
#
# Game 20
# Episode: 19, score: -20.0, avg_score: -20.2, best_score: -20.0, epsilon: 0.8097500000008658
#
# Game 21
# Episode: 20, score: -20.0, avg_score: -20.19047619047619, best_score: -20.0, epsilon: 0.7999300000009105
#
# Game 22
# Episode: 21, score: -21.0, avg_score: -20.227272727272727, best_score: -20.0, epsilon: 0.7910800000009508
#
# Game 23
# Episode: 22, score: -20.0, avg_score: -20.217391304347824, best_score: -20.0, epsilon: 0.7809800000009968
#
# Game 24
# Episode: 23, score: -20.0, avg_score: -20.208333333333332, best_score: -20.0, epsilon: 0.771710000001039
#
# Game 25
# Episode: 24, score: -19.0, avg_score: -20.16, best_score: -20.0, epsilon: 0.761370000001086
#
# Game 26
# Episode: 25, score: -21.0, avg_score: -20.192307692307693, best_score: -20.0, epsilon: 0.7515300000011308
#
# Game 27
# Episode: 26, score: -20.0, avg_score: -20.185185185185187, best_score: -20.0, epsilon: 0.741370000001177
#
# Game 28
# Episode: 27, score: -21.0, avg_score: -20.214285714285715, best_score: -20.0, epsilon: 0.7320700000012194
#
# Game 29
# Episode: 28, score: -21.0, avg_score: -20.24137931034483, best_score: -20.0, epsilon: 0.7235300000012582
#
# Game 30
# Episode: 29, score: -18.0, avg_score: -20.166666666666668, best_score: -20.0, epsilon: 0.7116800000013122
#
# Game 31
# Episode: 30, score: -21.0, avg_score: -20.193548387096776, best_score: -20.0, epsilon: 0.7019700000013563
#
# Game 32
# Episode: 31, score: -21.0, avg_score: -20.21875, best_score: -20.0, epsilon: 0.6904700000014087
#
# Game 33
# Episode: 32, score: -19.0, avg_score: -20.181818181818183, best_score: -20.0, epsilon: 0.6786900000014623
#
# Game 34
# Episode: 33, score: -17.0, avg_score: -20.08823529411765, best_score: -20.0, epsilon: 0.666440000001518
#
# Game 35
# Episode: 34, score: -20.0, avg_score: -20.085714285714285, best_score: -20.0, epsilon: 0.6547100000015714
#
# Game 36
# Episode: 35, score: -18.0, avg_score: -20.02777777777778, best_score: -20.0, epsilon: 0.6423800000016275
#
# Game 37
# Episode: 36, score: -18.0, avg_score: -19.972972972972972, best_score: -20.0, epsilon: 0.6307400000016805
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 38
# Episode: 37, score: -19.0, avg_score: -19.94736842105263, best_score: -19.972972972972972, epsilon: 0.61766000000174
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 39
# Episode: 38, score: -19.0, avg_score: -19.923076923076923, best_score: -19.94736842105263, epsilon: 0.6025800000018087
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 40
# Episode: 39, score: -20.0, avg_score: -19.925, best_score: -19.923076923076923, epsilon: 0.5916100000018586
#
# Game 41
# Episode: 40, score: -20.0, avg_score: -19.926829268292682, best_score: -19.923076923076923, epsilon: 0.5791500000019153
#
# Game 42
# Episode: 41, score: -17.0, avg_score: -19.857142857142858, best_score: -19.923076923076923, epsilon: 0.5611200000019974
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 43
# Episode: 42, score: -21.0, avg_score: -19.88372093023256, best_score: -19.857142857142858, epsilon: 0.5484000000020552
#
# Game 44
# Episode: 43, score: -19.0, avg_score: -19.863636363636363, best_score: -19.857142857142858, epsilon: 0.5364100000021098
#
# Game 45
# Episode: 44, score: -19.0, avg_score: -19.844444444444445, best_score: -19.857142857142858, epsilon: 0.5231200000021703
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 46
# Episode: 45, score: -20.0, avg_score: -19.847826086956523, best_score: -19.844444444444445, epsilon: 0.5101400000022294
#
# Game 47
# Episode: 46, score: -20.0, avg_score: -19.851063829787233, best_score: -19.844444444444445, epsilon: 0.4999700000022755
#
# Game 48
# Episode: 47, score: -17.0, avg_score: -19.791666666666668, best_score: -19.844444444444445, epsilon: 0.48514000000226065
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 49
# Episode: 48, score: -13.0, avg_score: -19.653061224489797, best_score: -19.791666666666668, epsilon: 0.4646100000022401
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 50
# Episode: 49, score: -17.0, avg_score: -19.6, best_score: -19.653061224489797, epsilon: 0.4490800000022246
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 51
# Episode: 50, score: -15.0, avg_score: -19.50980392156863, best_score: -19.6, epsilon: 0.4284000000022039
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 52
# Episode: 51, score: -18.0, avg_score: -19.48076923076923, best_score: -19.50980392156863, epsilon: 0.413520000002189
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 53
# Episode: 52, score: -19.0, avg_score: -19.471698113207548, best_score: -19.48076923076923, epsilon: 0.39554000000217104
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 54
# Episode: 53, score: -18.0, avg_score: -19.444444444444443, best_score: -19.471698113207548, epsilon: 0.3802100000021557
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 55
# Episode: 54, score: -18.0, avg_score: -19.418181818181818, best_score: -19.444444444444443, epsilon: 0.3645900000021401
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 56
# Episode: 55, score: -18.0, avg_score: -19.392857142857142, best_score: -19.418181818181818, epsilon: 0.3519000000021274
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 57
# Episode: 56, score: -17.0, avg_score: -19.350877192982455, best_score: -19.392857142857142, epsilon: 0.33507000000211057
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 58
# Episode: 57, score: -15.0, avg_score: -19.275862068965516, best_score: -19.350877192982455, epsilon: 0.31386000000208936
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 59
# Episode: 58, score: -15.0, avg_score: -19.203389830508474, best_score: -19.275862068965516, epsilon: 0.293530000002069
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 60
# Episode: 59, score: -16.0, avg_score: -19.15, best_score: -19.203389830508474, epsilon: 0.277530000002053
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 61
# Episode: 60, score: -12.0, avg_score: -19.0327868852459, best_score: -19.15, epsilon: 0.2560300000020315
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 62
# Episode: 61, score: -12.0, avg_score: -18.919354838709676, best_score: -19.0327868852459, epsilon: 0.23268000000200817
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 63
# Episode: 62, score: -17.0, avg_score: -18.88888888888889, best_score: -18.919354838709676, epsilon: 0.2132000000019887
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 64
# Episode: 63, score: -12.0, avg_score: -18.78125, best_score: -18.88888888888889, epsilon: 0.19248000000196797
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 65
# Episode: 64, score: -16.0, avg_score: -18.73846153846154, best_score: -18.78125, epsilon: 0.1709100000019464
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 66
# Episode: 65, score: -6.0, avg_score: -18.545454545454547, best_score: -18.73846153846154, epsilon: 0.14450000000191998
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 67
# Episode: 66, score: -14.0, avg_score: -18.47761194029851, best_score: -18.545454545454547, epsilon: 0.12438000000190072
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 68
# Episode: 67, score: -14.0, avg_score: -18.41176470588235, best_score: -18.47761194029851, epsilon: 0.10279000000190909
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 69
# Episode: 68, score: -7.0, avg_score: -18.246376811594203, best_score: -18.41176470588235, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 70
# Episode: 69, score: -8.0, avg_score: -18.1, best_score: -18.246376811594203, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 71
# Episode: 70, score: -10.0, avg_score: -17.985915492957748, best_score: -18.1, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 72
# Episode: 71, score: -11.0, avg_score: -17.88888888888889, best_score: -17.985915492957748, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 73
# Episode: 72, score: -9.0, avg_score: -17.767123287671232, best_score: -17.88888888888889, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 74
# Episode: 73, score: -10.0, avg_score: -17.66216216216216, best_score: -17.767123287671232, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 75
# Episode: 74, score: -7.0, avg_score: -17.52, best_score: -17.66216216216216, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 76
# Episode: 75, score: -6.0, avg_score: -17.36842105263158, best_score: -17.52, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 77
# Episode: 76, score: -5.0, avg_score: -17.207792207792206, best_score: -17.36842105263158, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 78
# Episode: 77, score: -5.0, avg_score: -17.05128205128205, best_score: -17.207792207792206, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 79
# Episode: 78, score: -4.0, avg_score: -16.88607594936709, best_score: -17.05128205128205, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 80
# Episode: 79, score: -2.0, avg_score: -16.7, best_score: -16.88607594936709, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 81
# Episode: 80, score: 2.0, avg_score: -16.469135802469136, best_score: -16.7, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 82
# Episode: 81, score: -11.0, avg_score: -16.402439024390244, best_score: -16.469135802469136, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 83
# Episode: 82, score: -7.0, avg_score: -16.289156626506024, best_score: -16.402439024390244, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 84
# Episode: 83, score: 5.0, avg_score: -16.035714285714285, best_score: -16.289156626506024, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 85
# Episode: 84, score: 2.0, avg_score: -15.823529411764707, best_score: -16.035714285714285, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 86
# Episode: 85, score: 9.0, avg_score: -15.534883720930232, best_score: -15.823529411764707, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 87
# Episode: 86, score: 4.0, avg_score: -15.310344827586206, best_score: -15.534883720930232, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 88
# Episode: 87, score: -7.0, avg_score: -15.215909090909092, best_score: -15.310344827586206, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 89
# Episode: 88, score: 2.0, avg_score: -15.02247191011236, best_score: -15.215909090909092, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 90
# Episode: 89, score: 13.0, avg_score: -14.71111111111111, best_score: -15.02247191011236, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 91
# Episode: 90, score: -6.0, avg_score: -14.615384615384615, best_score: -14.71111111111111, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 92
# Episode: 91, score: 7.0, avg_score: -14.380434782608695, best_score: -14.615384615384615, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 93
# Episode: 92, score: 8.0, avg_score: -14.13978494623656, best_score: -14.380434782608695, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 94
# Episode: 93, score: 12.0, avg_score: -13.861702127659575, best_score: -14.13978494623656, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 95
# Episode: 94, score: -1.0, avg_score: -13.726315789473684, best_score: -13.861702127659575, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 96
# Episode: 95, score: 9.0, avg_score: -13.489583333333334, best_score: -13.726315789473684, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 97
# Episode: 96, score: 13.0, avg_score: -13.216494845360824, best_score: -13.489583333333334, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 98
# Episode: 97, score: 14.0, avg_score: -12.938775510204081, best_score: -13.216494845360824, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 99
# Episode: 98, score: 8.0, avg_score: -12.727272727272727, best_score: -12.938775510204081, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 100
# Episode: 99, score: 8.0, avg_score: -12.52, best_score: -12.727272727272727, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 101
# Episode: 100, score: 4.0, avg_score: -12.27, best_score: -12.52, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 102
# Episode: 101, score: 10.0, avg_score: -11.97, best_score: -12.27, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 103
# Episode: 102, score: 4.0, avg_score: -11.74, best_score: -11.97, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 104
# Episode: 103, score: 3.0, avg_score: -11.51, best_score: -11.74, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 105
# Episode: 104, score: 8.0, avg_score: -11.22, best_score: -11.51, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 106
# Episode: 105, score: 17.0, avg_score: -10.84, best_score: -11.22, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 107
# Episode: 106, score: 17.0, avg_score: -10.47, best_score: -10.84, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 108
# Episode: 107, score: 3.0, avg_score: -10.23, best_score: -10.47, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 109
# Episode: 108, score: 18.0, avg_score: -9.85, best_score: -10.23, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 110
# Episode: 109, score: 13.0, avg_score: -9.51, best_score: -9.85, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 111
# Episode: 110, score: 15.0, avg_score: -9.17, best_score: -9.51, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 112
# Episode: 111, score: 17.0, avg_score: -8.79, best_score: -9.17, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 113
# Episode: 112, score: 10.0, avg_score: -8.48, best_score: -8.79, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 114
# Episode: 113, score: 16.0, avg_score: -8.11, best_score: -8.48, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 115
# Episode: 114, score: 15.0, avg_score: -7.75, best_score: -8.11, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 116
# Episode: 115, score: 6.0, avg_score: -7.48, best_score: -7.75, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 117
# Episode: 116, score: 6.0, avg_score: -7.23, best_score: -7.48, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 118
# Episode: 117, score: 13.0, avg_score: -6.92, best_score: -7.23, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 119
# Episode: 118, score: 14.0, avg_score: -6.59, best_score: -6.92, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 120
# Episode: 119, score: 15.0, avg_score: -6.24, best_score: -6.59, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 121
# Episode: 120, score: 17.0, avg_score: -5.87, best_score: -6.24, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 122
# Episode: 121, score: 8.0, avg_score: -5.58, best_score: -5.87, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 123
# Episode: 122, score: 14.0, avg_score: -5.24, best_score: -5.58, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 124
# Episode: 123, score: 15.0, avg_score: -4.89, best_score: -5.24, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 125
# Episode: 124, score: 16.0, avg_score: -4.54, best_score: -4.89, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 126
# Episode: 125, score: 9.0, avg_score: -4.24, best_score: -4.54, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 127
# Episode: 126, score: 13.0, avg_score: -3.91, best_score: -4.24, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 128
# Episode: 127, score: 9.0, avg_score: -3.61, best_score: -3.91, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 129
# Episode: 128, score: 12.0, avg_score: -3.28, best_score: -3.61, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 130
# Episode: 129, score: 13.0, avg_score: -2.97, best_score: -3.28, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 131
# Episode: 130, score: 17.0, avg_score: -2.59, best_score: -2.97, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 132
# Episode: 131, score: 13.0, avg_score: -2.25, best_score: -2.59, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 133
# Episode: 132, score: 12.0, avg_score: -1.94, best_score: -2.25, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 134
# Episode: 133, score: 14.0, avg_score: -1.63, best_score: -1.94, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 135
# Episode: 134, score: 8.0, avg_score: -1.35, best_score: -1.63, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 136
# Episode: 135, score: 9.0, avg_score: -1.08, best_score: -1.35, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 137
# Episode: 136, score: 19.0, avg_score: -0.71, best_score: -1.08, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 138
# Episode: 137, score: 17.0, avg_score: -0.35, best_score: -0.71, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 139
# Episode: 138, score: 9.0, avg_score: -0.07, best_score: -0.35, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 140
# Episode: 139, score: 16.0, avg_score: 0.29, best_score: -0.07, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 141
# Episode: 140, score: 19.0, avg_score: 0.68, best_score: 0.29, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 142
# Episode: 141, score: 6.0, avg_score: 0.91, best_score: 0.68, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 143
# Episode: 142, score: 6.0, avg_score: 1.18, best_score: 0.91, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 144
# Episode: 143, score: 10.0, avg_score: 1.47, best_score: 1.18, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 145
# Episode: 144, score: 13.0, avg_score: 1.79, best_score: 1.47, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 146
# Episode: 145, score: 15.0, avg_score: 2.14, best_score: 1.79, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 147
# Episode: 146, score: 15.0, avg_score: 2.49, best_score: 2.14, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 148
# Episode: 147, score: 14.0, avg_score: 2.8, best_score: 2.49, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 149
# Episode: 148, score: 16.0, avg_score: 3.09, best_score: 2.8, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 150
# Episode: 149, score: 14.0, avg_score: 3.4, best_score: 3.09, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 151
# Episode: 150, score: 14.0, avg_score: 3.69, best_score: 3.4, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 152
# Episode: 151, score: 9.0, avg_score: 3.96, best_score: 3.69, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 153
# Episode: 152, score: 8.0, avg_score: 4.23, best_score: 3.96, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 154
# Episode: 153, score: 12.0, avg_score: 4.53, best_score: 4.23, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 155
# Episode: 154, score: 10.0, avg_score: 4.81, best_score: 4.53, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 156
# Episode: 155, score: 6.0, avg_score: 5.05, best_score: 4.81, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 157
# Episode: 156, score: 7.0, avg_score: 5.29, best_score: 5.05, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 158
# Episode: 157, score: 19.0, avg_score: 5.63, best_score: 5.29, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 159
# Episode: 158, score: 10.0, avg_score: 5.88, best_score: 5.63, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 160
# Episode: 159, score: 14.0, avg_score: 6.18, best_score: 5.88, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 161
# Episode: 160, score: 10.0, avg_score: 6.4, best_score: 6.18, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 162
# Episode: 161, score: 15.0, avg_score: 6.67, best_score: 6.4, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 163
# Episode: 162, score: 17.0, avg_score: 7.01, best_score: 6.67, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 164
# Episode: 163, score: 11.0, avg_score: 7.24, best_score: 7.01, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 165
# Episode: 164, score: 14.0, avg_score: 7.54, best_score: 7.24, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 166
# Episode: 165, score: 9.0, avg_score: 7.69, best_score: 7.54, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 167
# Episode: 166, score: 15.0, avg_score: 7.98, best_score: 7.69, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 168
# Episode: 167, score: 14.0, avg_score: 8.26, best_score: 7.98, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 169
# Episode: 168, score: 16.0, avg_score: 8.49, best_score: 8.26, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 170
# Episode: 169, score: 11.0, avg_score: 8.68, best_score: 8.49, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 171
# Episode: 170, score: 17.0, avg_score: 8.95, best_score: 8.68, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 172
# Episode: 171, score: 14.0, avg_score: 9.2, best_score: 8.95, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 173
# Episode: 172, score: 15.0, avg_score: 9.44, best_score: 9.2, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 174
# Episode: 173, score: 5.0, avg_score: 9.59, best_score: 9.44, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 175
# Episode: 174, score: 6.0, avg_score: 9.72, best_score: 9.59, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 176
# Episode: 175, score: 17.0, avg_score: 9.95, best_score: 9.72, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 177
# Episode: 176, score: 15.0, avg_score: 10.15, best_score: 9.95, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 178
# Episode: 177, score: 18.0, avg_score: 10.38, best_score: 10.15, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 179
# Episode: 178, score: 19.0, avg_score: 10.61, best_score: 10.38, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 180
# Episode: 179, score: 15.0, avg_score: 10.78, best_score: 10.61, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 181
# Episode: 180, score: 9.0, avg_score: 10.85, best_score: 10.78, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 182
# Episode: 181, score: 19.0, avg_score: 11.15, best_score: 10.85, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 183
# Episode: 182, score: 17.0, avg_score: 11.39, best_score: 11.15, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 184
# Episode: 183, score: 12.0, avg_score: 11.46, best_score: 11.39, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 185
# Episode: 184, score: 17.0, avg_score: 11.61, best_score: 11.46, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 186
# Episode: 185, score: 15.0, avg_score: 11.67, best_score: 11.61, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 187
# Episode: 186, score: 14.0, avg_score: 11.77, best_score: 11.67, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 188
# Episode: 187, score: 16.0, avg_score: 12.0, best_score: 11.77, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 189
# Episode: 188, score: 13.0, avg_score: 12.11, best_score: 12.0, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 190
# Episode: 189, score: 8.0, avg_score: 12.06, best_score: 12.11, epsilon: 0.1
#
# Game 191
# Episode: 190, score: 11.0, avg_score: 12.23, best_score: 12.11, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 192
# Episode: 191, score: 7.0, avg_score: 12.23, best_score: 12.23, epsilon: 0.1
#
# Game 193
# Episode: 192, score: 15.0, avg_score: 12.3, best_score: 12.23, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 194
# Episode: 193, score: 5.0, avg_score: 12.23, best_score: 12.3, epsilon: 0.1
#
# Game 195
# Episode: 194, score: 11.0, avg_score: 12.35, best_score: 12.3, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 196
# Episode: 195, score: 9.0, avg_score: 12.35, best_score: 12.35, epsilon: 0.1
#
# Game 197
# Episode: 196, score: 16.0, avg_score: 12.38, best_score: 12.35, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 198
# Episode: 197, score: 10.0, avg_score: 12.34, best_score: 12.38, epsilon: 0.1
#
# Game 199
# Episode: 198, score: 7.0, avg_score: 12.33, best_score: 12.38, epsilon: 0.1
#
# Game 200
# Episode: 199, score: 17.0, avg_score: 12.42, best_score: 12.38, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 201
# Episode: 200, score: 18.0, avg_score: 12.56, best_score: 12.42, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 202
# Episode: 201, score: 15.0, avg_score: 12.61, best_score: 12.56, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 203
# Episode: 202, score: 14.0, avg_score: 12.71, best_score: 12.61, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 204
# Episode: 203, score: 14.0, avg_score: 12.82, best_score: 12.71, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 205
# Episode: 204, score: 10.0, avg_score: 12.84, best_score: 12.82, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 206
# Episode: 205, score: 13.0, avg_score: 12.8, best_score: 12.84, epsilon: 0.1
#
# Game 207
# Episode: 206, score: 14.0, avg_score: 12.77, best_score: 12.84, epsilon: 0.1
#
# Game 208
# Episode: 207, score: 8.0, avg_score: 12.82, best_score: 12.84, epsilon: 0.1
#
# Game 209
# Episode: 208, score: 15.0, avg_score: 12.79, best_score: 12.84, epsilon: 0.1
#
# Game 210
# Episode: 209, score: 11.0, avg_score: 12.77, best_score: 12.84, epsilon: 0.1
#
# Game 211
# Episode: 210, score: 14.0, avg_score: 12.76, best_score: 12.84, epsilon: 0.1
#
# Game 212
# Episode: 211, score: 14.0, avg_score: 12.73, best_score: 12.84, epsilon: 0.1
#
# Game 213
# Episode: 212, score: 17.0, avg_score: 12.8, best_score: 12.84, epsilon: 0.1
#
# Game 214
# Episode: 213, score: 15.0, avg_score: 12.79, best_score: 12.84, epsilon: 0.1
#
# Game 215
# Episode: 214, score: 12.0, avg_score: 12.76, best_score: 12.84, epsilon: 0.1
#
# Game 216
# Episode: 215, score: 18.0, avg_score: 12.88, best_score: 12.84, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 217
# Episode: 216, score: 16.0, avg_score: 12.98, best_score: 12.88, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 218
# Episode: 217, score: 16.0, avg_score: 13.01, best_score: 12.98, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 219
# Episode: 218, score: 17.0, avg_score: 13.04, best_score: 13.01, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 220
# Episode: 219, score: 11.0, avg_score: 13.0, best_score: 13.04, epsilon: 0.1
#
# Game 221
# Episode: 220, score: 16.0, avg_score: 12.99, best_score: 13.04, epsilon: 0.1
#
# Game 222
# Episode: 221, score: 13.0, avg_score: 13.04, best_score: 13.04, epsilon: 0.1
#
# Game 223
# Episode: 222, score: 19.0, avg_score: 13.09, best_score: 13.04, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 224
# Episode: 223, score: 17.0, avg_score: 13.11, best_score: 13.09, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 225
# Episode: 224, score: 18.0, avg_score: 13.13, best_score: 13.11, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 226
# Episode: 225, score: 18.0, avg_score: 13.22, best_score: 13.13, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 227
# Episode: 226, score: 14.0, avg_score: 13.23, best_score: 13.22, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 228
# Episode: 227, score: 14.0, avg_score: 13.28, best_score: 13.23, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 229
# Episode: 228, score: 14.0, avg_score: 13.3, best_score: 13.28, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 230
# Episode: 229, score: 14.0, avg_score: 13.31, best_score: 13.3, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 231
# Episode: 230, score: 13.0, avg_score: 13.27, best_score: 13.31, epsilon: 0.1
#
# Game 232
# Episode: 231, score: 10.0, avg_score: 13.24, best_score: 13.31, epsilon: 0.1
#
# Game 233
# Episode: 232, score: 7.0, avg_score: 13.19, best_score: 13.31, epsilon: 0.1
#
# Game 234
# Episode: 233, score: 13.0, avg_score: 13.18, best_score: 13.31, epsilon: 0.1
#
# Game 235
# Episode: 234, score: 19.0, avg_score: 13.29, best_score: 13.31, epsilon: 0.1
#
# Game 236
# Episode: 235, score: 19.0, avg_score: 13.39, best_score: 13.31, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 237
# Episode: 236, score: 11.0, avg_score: 13.31, best_score: 13.39, epsilon: 0.1
#
# Game 238
# Episode: 237, score: 15.0, avg_score: 13.29, best_score: 13.39, epsilon: 0.1
#
# Game 239
# Episode: 238, score: 14.0, avg_score: 13.34, best_score: 13.39, epsilon: 0.1
#
# Game 240
# Episode: 239, score: 16.0, avg_score: 13.34, best_score: 13.39, epsilon: 0.1
#
# Game 241
# Episode: 240, score: 8.0, avg_score: 13.23, best_score: 13.39, epsilon: 0.1
#
# Game 242
# Episode: 241, score: 19.0, avg_score: 13.36, best_score: 13.39, epsilon: 0.1
#
# Game 243
# Episode: 242, score: 19.0, avg_score: 13.49, best_score: 13.39, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 244
# Episode: 243, score: 20.0, avg_score: 13.59, best_score: 13.49, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 245
# Episode: 244, score: 14.0, avg_score: 13.6, best_score: 13.59, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 246
# Episode: 245, score: 15.0, avg_score: 13.6, best_score: 13.6, epsilon: 0.1
#
# Game 247
# Episode: 246, score: 19.0, avg_score: 13.64, best_score: 13.6, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 248
# Episode: 247, score: 13.0, avg_score: 13.63, best_score: 13.64, epsilon: 0.1
#
# Game 249
# Episode: 248, score: 10.0, avg_score: 13.57, best_score: 13.64, epsilon: 0.1
#
# Game 250
# Episode: 249, score: 19.0, avg_score: 13.62, best_score: 13.64, epsilon: 0.1
#
# Game 251
# Episode: 250, score: 18.0, avg_score: 13.66, best_score: 13.64, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 252
# Episode: 251, score: 14.0, avg_score: 13.71, best_score: 13.66, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 253
# Episode: 252, score: 17.0, avg_score: 13.8, best_score: 13.71, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 254
# Episode: 253, score: 19.0, avg_score: 13.87, best_score: 13.8, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 255
# Episode: 254, score: 17.0, avg_score: 13.94, best_score: 13.87, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 256
# Episode: 255, score: 17.0, avg_score: 14.05, best_score: 13.94, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 257
# Episode: 256, score: 13.0, avg_score: 14.11, best_score: 14.05, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 258
# Episode: 257, score: 17.0, avg_score: 14.09, best_score: 14.11, epsilon: 0.1
#
# Game 259
# Episode: 258, score: 20.0, avg_score: 14.19, best_score: 14.11, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 260
# Episode: 259, score: 14.0, avg_score: 14.19, best_score: 14.19, epsilon: 0.1
#
# Game 261
# Episode: 260, score: 15.0, avg_score: 14.24, best_score: 14.19, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 262
# Episode: 261, score: 20.0, avg_score: 14.29, best_score: 14.24, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 263
# Episode: 262, score: 19.0, avg_score: 14.31, best_score: 14.29, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 264
# Episode: 263, score: 10.0, avg_score: 14.3, best_score: 14.31, epsilon: 0.1
#
# Game 265
# Episode: 264, score: 17.0, avg_score: 14.33, best_score: 14.31, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 266
# Episode: 265, score: 13.0, avg_score: 14.37, best_score: 14.33, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 267
# Episode: 266, score: 15.0, avg_score: 14.37, best_score: 14.37, epsilon: 0.1
#
# Game 268
# Episode: 267, score: 17.0, avg_score: 14.4, best_score: 14.37, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 269
# Episode: 268, score: 15.0, avg_score: 14.39, best_score: 14.4, epsilon: 0.1
#
# Game 270
# Episode: 269, score: 14.0, avg_score: 14.42, best_score: 14.4, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 271
# Episode: 270, score: 15.0, avg_score: 14.4, best_score: 14.42, epsilon: 0.1
#
# Game 272
# Episode: 271, score: 18.0, avg_score: 14.44, best_score: 14.42, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 273
# Episode: 272, score: 13.0, avg_score: 14.42, best_score: 14.44, epsilon: 0.1
#
# Game 274
# Episode: 273, score: 11.0, avg_score: 14.48, best_score: 14.44, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 275
# Episode: 274, score: 16.0, avg_score: 14.58, best_score: 14.48, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 276
# Episode: 275, score: 18.0, avg_score: 14.59, best_score: 14.58, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 277
# Episode: 276, score: 20.0, avg_score: 14.64, best_score: 14.59, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 278
# Episode: 277, score: 18.0, avg_score: 14.64, best_score: 14.64, epsilon: 0.1
#
# Game 279
# Episode: 278, score: 10.0, avg_score: 14.55, best_score: 14.64, epsilon: 0.1
#
# Game 280
# Episode: 279, score: 17.0, avg_score: 14.57, best_score: 14.64, epsilon: 0.1
#
# Game 281
# Episode: 280, score: 18.0, avg_score: 14.66, best_score: 14.64, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 282
# Episode: 281, score: 19.0, avg_score: 14.66, best_score: 14.66, epsilon: 0.1
#
# Game 283
# Episode: 282, score: 16.0, avg_score: 14.65, best_score: 14.66, epsilon: 0.1
#
# Game 284
# Episode: 283, score: 15.0, avg_score: 14.68, best_score: 14.66, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 285
# Episode: 284, score: 15.0, avg_score: 14.66, best_score: 14.68, epsilon: 0.1
#
# Game 286
# Episode: 285, score: 6.0, avg_score: 14.57, best_score: 14.68, epsilon: 0.1
#
# Game 287
# Episode: 286, score: 12.0, avg_score: 14.55, best_score: 14.68, epsilon: 0.1
#
# Game 288
# Episode: 287, score: 17.0, avg_score: 14.56, best_score: 14.68, epsilon: 0.1
#
# Game 289
# Episode: 288, score: 10.0, avg_score: 14.53, best_score: 14.68, epsilon: 0.1
#
# Game 290
# Episode: 289, score: 14.0, avg_score: 14.59, best_score: 14.68, epsilon: 0.1
#
# Game 291
# Episode: 290, score: 17.0, avg_score: 14.65, best_score: 14.68, epsilon: 0.1
#
# Game 292
# Episode: 291, score: 14.0, avg_score: 14.72, best_score: 14.68, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 293
# Episode: 292, score: 15.0, avg_score: 14.72, best_score: 14.72, epsilon: 0.1
#
# Game 294
# Episode: 293, score: 14.0, avg_score: 14.81, best_score: 14.72, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 295
# Episode: 294, score: 18.0, avg_score: 14.88, best_score: 14.81, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 296
# Episode: 295, score: 14.0, avg_score: 14.93, best_score: 14.88, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 297
# Episode: 296, score: 10.0, avg_score: 14.87, best_score: 14.93, epsilon: 0.1
#
# Game 298
# Episode: 297, score: 14.0, avg_score: 14.91, best_score: 14.93, epsilon: 0.1
#
# Game 299
# Episode: 298, score: 13.0, avg_score: 14.97, best_score: 14.93, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 300
# Episode: 299, score: 13.0, avg_score: 14.93, best_score: 14.97, epsilon: 0.1
#
# Game 301
# Episode: 300, score: 14.0, avg_score: 14.89, best_score: 14.97, epsilon: 0.1
#
# Game 302
# Episode: 301, score: 16.0, avg_score: 14.9, best_score: 14.97, epsilon: 0.1
#
# Game 303
# Episode: 302, score: 14.0, avg_score: 14.9, best_score: 14.97, epsilon: 0.1
#
# Game 304
# Episode: 303, score: 17.0, avg_score: 14.93, best_score: 14.97, epsilon: 0.1
#
# Game 305
# Episode: 304, score: 13.0, avg_score: 14.96, best_score: 14.97, epsilon: 0.1
#
# Game 306
# Episode: 305, score: 18.0, avg_score: 15.01, best_score: 14.97, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 307
# Episode: 306, score: 15.0, avg_score: 15.02, best_score: 15.01, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 308
# Episode: 307, score: 17.0, avg_score: 15.11, best_score: 15.02, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 309
# Episode: 308, score: 17.0, avg_score: 15.13, best_score: 15.11, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 310
# Episode: 309, score: 20.0, avg_score: 15.22, best_score: 15.13, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 311
# Episode: 310, score: 14.0, avg_score: 15.22, best_score: 15.22, epsilon: 0.1
#
# Game 312
# Episode: 311, score: 19.0, avg_score: 15.27, best_score: 15.22, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 313
# Episode: 312, score: 17.0, avg_score: 15.27, best_score: 15.27, epsilon: 0.1
#
# Game 314
# Episode: 313, score: 19.0, avg_score: 15.31, best_score: 15.27, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 315
# Episode: 314, score: 16.0, avg_score: 15.35, best_score: 15.31, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 316
# Episode: 315, score: 17.0, avg_score: 15.34, best_score: 15.35, epsilon: 0.1
#
# Game 317
# Episode: 316, score: 14.0, avg_score: 15.32, best_score: 15.35, epsilon: 0.1
#
# Game 318
# Episode: 317, score: 21.0, avg_score: 15.37, best_score: 15.35, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 319
# Episode: 318, score: 12.0, avg_score: 15.32, best_score: 15.37, epsilon: 0.1
#
# Game 320
# Episode: 319, score: 15.0, avg_score: 15.36, best_score: 15.37, epsilon: 0.1
#
# Game 321
# Episode: 320, score: 5.0, avg_score: 15.25, best_score: 15.37, epsilon: 0.1
#
# Game 322
# Episode: 321, score: 17.0, avg_score: 15.29, best_score: 15.37, epsilon: 0.1
#
# Game 323
# Episode: 322, score: 20.0, avg_score: 15.3, best_score: 15.37, epsilon: 0.1
#
# Game 324
# Episode: 323, score: 11.0, avg_score: 15.24, best_score: 15.37, epsilon: 0.1
#
# Game 325
# Episode: 324, score: 14.0, avg_score: 15.2, best_score: 15.37, epsilon: 0.1
#
# Game 326
# Episode: 325, score: 19.0, avg_score: 15.21, best_score: 15.37, epsilon: 0.1
#
# Game 327
# Episode: 326, score: 17.0, avg_score: 15.24, best_score: 15.37, epsilon: 0.1
#
# Game 328
# Episode: 327, score: 13.0, avg_score: 15.23, best_score: 15.37, epsilon: 0.1
#
# Game 329
# Episode: 328, score: 16.0, avg_score: 15.25, best_score: 15.37, epsilon: 0.1
#
# Game 330
# Episode: 329, score: 12.0, avg_score: 15.23, best_score: 15.37, epsilon: 0.1
#
# Game 331
# Episode: 330, score: 17.0, avg_score: 15.27, best_score: 15.37, epsilon: 0.1
#
# Game 332
# Episode: 331, score: 15.0, avg_score: 15.32, best_score: 15.37, epsilon: 0.1
#
# Game 333
# Episode: 332, score: 18.0, avg_score: 15.43, best_score: 15.37, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 334
# Episode: 333, score: 15.0, avg_score: 15.45, best_score: 15.43, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 335
# Episode: 334, score: 12.0, avg_score: 15.38, best_score: 15.45, epsilon: 0.1
#
# Game 336
# Episode: 335, score: 12.0, avg_score: 15.31, best_score: 15.45, epsilon: 0.1
#
# Game 337
# Episode: 336, score: 15.0, avg_score: 15.35, best_score: 15.45, epsilon: 0.1
#
# Game 338
# Episode: 337, score: 18.0, avg_score: 15.38, best_score: 15.45, epsilon: 0.1
#
# Game 339
# Episode: 338, score: 18.0, avg_score: 15.42, best_score: 15.45, epsilon: 0.1
#
# Game 340
# Episode: 339, score: -1.0, avg_score: 15.25, best_score: 15.45, epsilon: 0.1
#
# Game 341
# Episode: 340, score: 8.0, avg_score: 15.25, best_score: 15.45, epsilon: 0.1
#
# Game 342
# Episode: 341, score: 18.0, avg_score: 15.24, best_score: 15.45, epsilon: 0.1
#
# Game 343
# Episode: 342, score: 20.0, avg_score: 15.25, best_score: 15.45, epsilon: 0.1
#
# Game 344
# Episode: 343, score: 12.0, avg_score: 15.17, best_score: 15.45, epsilon: 0.1
#
# Game 345
# Episode: 344, score: 16.0, avg_score: 15.19, best_score: 15.45, epsilon: 0.1
#
# Game 346
# Episode: 345, score: 19.0, avg_score: 15.23, best_score: 15.45, epsilon: 0.1
#
# Game 347
# Episode: 346, score: 14.0, avg_score: 15.18, best_score: 15.45, epsilon: 0.1
#
# Game 348
# Episode: 347, score: 12.0, avg_score: 15.17, best_score: 15.45, epsilon: 0.1
#
# Game 349
# Episode: 348, score: 18.0, avg_score: 15.25, best_score: 15.45, epsilon: 0.1
#
# Game 350
# Episode: 349, score: 16.0, avg_score: 15.22, best_score: 15.45, epsilon: 0.1
#
# Game 351
# Episode: 350, score: 19.0, avg_score: 15.23, best_score: 15.45, epsilon: 0.1
#
# Game 352
# Episode: 351, score: 15.0, avg_score: 15.24, best_score: 15.45, epsilon: 0.1
#
# Game 353
# Episode: 352, score: 18.0, avg_score: 15.25, best_score: 15.45, epsilon: 0.1
#
# Game 354
# Episode: 353, score: 14.0, avg_score: 15.2, best_score: 15.45, epsilon: 0.1
#
# Game 355
# Episode: 354, score: 18.0, avg_score: 15.21, best_score: 15.45, epsilon: 0.1
#
# Game 356
# Episode: 355, score: 13.0, avg_score: 15.17, best_score: 15.45, epsilon: 0.1
#
# Game 357
# Episode: 356, score: 21.0, avg_score: 15.25, best_score: 15.45, epsilon: 0.1
#
# Game 358
# Episode: 357, score: 12.0, avg_score: 15.2, best_score: 15.45, epsilon: 0.1
#
# Game 359
# Episode: 358, score: 17.0, avg_score: 15.17, best_score: 15.45, epsilon: 0.1
#
# Game 360
# Episode: 359, score: 13.0, avg_score: 15.16, best_score: 15.45, epsilon: 0.1
#
# Game 361
# Episode: 360, score: 12.0, avg_score: 15.13, best_score: 15.45, epsilon: 0.1
#
# Game 362
# Episode: 361, score: 11.0, avg_score: 15.04, best_score: 15.45, epsilon: 0.1
#
# Game 363
# Episode: 362, score: 15.0, avg_score: 15.0, best_score: 15.45, epsilon: 0.1
#
# Game 364
# Episode: 363, score: 16.0, avg_score: 15.06, best_score: 15.45, epsilon: 0.1
#
# Game 365
# Episode: 364, score: 15.0, avg_score: 15.04, best_score: 15.45, epsilon: 0.1
#
# Game 366
# Episode: 365, score: 17.0, avg_score: 15.08, best_score: 15.45, epsilon: 0.1
#
# Game 367
# Episode: 366, score: 16.0, avg_score: 15.09, best_score: 15.45, epsilon: 0.1
#
# Game 368
# Episode: 367, score: 14.0, avg_score: 15.06, best_score: 15.45, epsilon: 0.1
#
# Game 369
# Episode: 368, score: 16.0, avg_score: 15.07, best_score: 15.45, epsilon: 0.1
#
# Game 370
# Episode: 369, score: 18.0, avg_score: 15.11, best_score: 15.45, epsilon: 0.1
#
# Game 371
# Episode: 370, score: 14.0, avg_score: 15.1, best_score: 15.45, epsilon: 0.1
#
# Game 372
# Episode: 371, score: 12.0, avg_score: 15.04, best_score: 15.45, epsilon: 0.1
#
# Game 373
# Episode: 372, score: 19.0, avg_score: 15.1, best_score: 15.45, epsilon: 0.1
#
# Game 374
# Episode: 373, score: 15.0, avg_score: 15.14, best_score: 15.45, epsilon: 0.1
#
# Game 375
# Episode: 374, score: 15.0, avg_score: 15.13, best_score: 15.45, epsilon: 0.1
#
# Game 376
# Episode: 375, score: 15.0, avg_score: 15.1, best_score: 15.45, epsilon: 0.1
#
# Game 377
# Episode: 376, score: 18.0, avg_score: 15.08, best_score: 15.45, epsilon: 0.1
#
# Game 378
# Episode: 377, score: 17.0, avg_score: 15.07, best_score: 15.45, epsilon: 0.1
#
# Game 379
# Episode: 378, score: 14.0, avg_score: 15.11, best_score: 15.45, epsilon: 0.1
#
# Game 380
# Episode: 379, score: 18.0, avg_score: 15.12, best_score: 15.45, epsilon: 0.1
#
# Game 381
# Episode: 380, score: 9.0, avg_score: 15.03, best_score: 15.45, epsilon: 0.1
#
# Game 382
# Episode: 381, score: 6.0, avg_score: 14.9, best_score: 15.45, epsilon: 0.1
#
# Game 383
# Episode: 382, score: 17.0, avg_score: 14.91, best_score: 15.45, epsilon: 0.1
#
# Game 384
# Episode: 383, score: 16.0, avg_score: 14.92, best_score: 15.45, epsilon: 0.1
#
# Game 385
# Episode: 384, score: 14.0, avg_score: 14.91, best_score: 15.45, epsilon: 0.1
#
# Game 386
# Episode: 385, score: 12.0, avg_score: 14.97, best_score: 15.45, epsilon: 0.1
#
# Game 387
# Episode: 386, score: 17.0, avg_score: 15.02, best_score: 15.45, epsilon: 0.1
#
# Game 388
# Episode: 387, score: 18.0, avg_score: 15.03, best_score: 15.45, epsilon: 0.1
#
# Game 389
# Episode: 388, score: 14.0, avg_score: 15.07, best_score: 15.45, epsilon: 0.1
#
# Game 390
# Episode: 389, score: 18.0, avg_score: 15.11, best_score: 15.45, epsilon: 0.1
#
# Game 391
# Episode: 390, score: 15.0, avg_score: 15.09, best_score: 15.45, epsilon: 0.1
#
# Game 392
# Episode: 391, score: 15.0, avg_score: 15.1, best_score: 15.45, epsilon: 0.1
#
# Game 393
# Episode: 392, score: 12.0, avg_score: 15.07, best_score: 15.45, epsilon: 0.1
#
# Game 394
# Episode: 393, score: 18.0, avg_score: 15.11, best_score: 15.45, epsilon: 0.1
#
# Game 395
# Episode: 394, score: 18.0, avg_score: 15.11, best_score: 15.45, epsilon: 0.1
#
# Game 396
# Episode: 395, score: 18.0, avg_score: 15.15, best_score: 15.45, epsilon: 0.1
#
# Game 397
# Episode: 396, score: 19.0, avg_score: 15.24, best_score: 15.45, epsilon: 0.1
#
# Game 398
# Episode: 397, score: 19.0, avg_score: 15.29, best_score: 15.45, epsilon: 0.1
#
# Game 399
# Episode: 398, score: 13.0, avg_score: 15.29, best_score: 15.45, epsilon: 0.1
#
# Game 400
# Episode: 399, score: 18.0, avg_score: 15.34, best_score: 15.45, epsilon: 0.1
#
# Game 401
# Episode: 400, score: 19.0, avg_score: 15.39, best_score: 15.45, epsilon: 0.1
#
# Game 402
# Episode: 401, score: 18.0, avg_score: 15.41, best_score: 15.45, epsilon: 0.1
#
# Game 403
# Episode: 402, score: 16.0, avg_score: 15.43, best_score: 15.45, epsilon: 0.1
#
# Game 404
# Episode: 403, score: 17.0, avg_score: 15.43, best_score: 15.45, epsilon: 0.1
#
# Game 405
# Episode: 404, score: 17.0, avg_score: 15.47, best_score: 15.45, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 406
# Episode: 405, score: 21.0, avg_score: 15.5, best_score: 15.47, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 407
# Episode: 406, score: 15.0, avg_score: 15.5, best_score: 15.5, epsilon: 0.1
#
# Game 408
# Episode: 407, score: 19.0, avg_score: 15.52, best_score: 15.5, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 409
# Episode: 408, score: 15.0, avg_score: 15.5, best_score: 15.52, epsilon: 0.1
#
# Game 410
# Episode: 409, score: 15.0, avg_score: 15.45, best_score: 15.52, epsilon: 0.1
#
# Game 411
# Episode: 410, score: 15.0, avg_score: 15.46, best_score: 15.52, epsilon: 0.1
#
# Game 412
# Episode: 411, score: 16.0, avg_score: 15.43, best_score: 15.52, epsilon: 0.1
#
# Game 413
# Episode: 412, score: 19.0, avg_score: 15.45, best_score: 15.52, epsilon: 0.1
#
# Game 414
# Episode: 413, score: 18.0, avg_score: 15.44, best_score: 15.52, epsilon: 0.1
#
# Game 415
# Episode: 414, score: 16.0, avg_score: 15.44, best_score: 15.52, epsilon: 0.1
#
# Game 416
# Episode: 415, score: 16.0, avg_score: 15.43, best_score: 15.52, epsilon: 0.1
#
# Game 417
# Episode: 416, score: 15.0, avg_score: 15.44, best_score: 15.52, epsilon: 0.1
#
# Game 418
# Episode: 417, score: 13.0, avg_score: 15.36, best_score: 15.52, epsilon: 0.1
#
# Game 419
# Episode: 418, score: 17.0, avg_score: 15.41, best_score: 15.52, epsilon: 0.1
#
# Game 420
# Episode: 419, score: 9.0, avg_score: 15.35, best_score: 15.52, epsilon: 0.1
#
# Game 421
# Episode: 420, score: 17.0, avg_score: 15.47, best_score: 15.52, epsilon: 0.1
#
# Game 422
# Episode: 421, score: 17.0, avg_score: 15.47, best_score: 15.52, epsilon: 0.1
#
# Game 423
# Episode: 422, score: 12.0, avg_score: 15.39, best_score: 15.52, epsilon: 0.1
#
# Game 424
# Episode: 423, score: 17.0, avg_score: 15.45, best_score: 15.52, epsilon: 0.1
#
# Game 425
# Episode: 424, score: 19.0, avg_score: 15.5, best_score: 15.52, epsilon: 0.1
#
# Game 426
# Episode: 425, score: 20.0, avg_score: 15.51, best_score: 15.52, epsilon: 0.1
#
# Game 427
# Episode: 426, score: 15.0, avg_score: 15.49, best_score: 15.52, epsilon: 0.1
#
# Game 428
# Episode: 427, score: 19.0, avg_score: 15.55, best_score: 15.52, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 429
# Episode: 428, score: 16.0, avg_score: 15.55, best_score: 15.55, epsilon: 0.1
#
# Game 430
# Episode: 429, score: 16.0, avg_score: 15.59, best_score: 15.55, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 431
# Episode: 430, score: 19.0, avg_score: 15.61, best_score: 15.59, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 432
# Episode: 431, score: 18.0, avg_score: 15.64, best_score: 15.61, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 433
# Episode: 432, score: 10.0, avg_score: 15.56, best_score: 15.64, epsilon: 0.1
#
# Game 434
# Episode: 433, score: 20.0, avg_score: 15.61, best_score: 15.64, epsilon: 0.1
#
# Game 435
# Episode: 434, score: 17.0, avg_score: 15.66, best_score: 15.64, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 436
# Episode: 435, score: 18.0, avg_score: 15.72, best_score: 15.66, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 437
# Episode: 436, score: 14.0, avg_score: 15.71, best_score: 15.72, epsilon: 0.1
#
# Game 438
# Episode: 437, score: 14.0, avg_score: 15.67, best_score: 15.72, epsilon: 0.1
#
# Game 439
# Episode: 438, score: 15.0, avg_score: 15.64, best_score: 15.72, epsilon: 0.1
#
# Game 440
# Episode: 439, score: 15.0, avg_score: 15.8, best_score: 15.72, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 441
# Episode: 440, score: 16.0, avg_score: 15.88, best_score: 15.8, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 442
# Episode: 441, score: 18.0, avg_score: 15.88, best_score: 15.88, epsilon: 0.1
#
# Game 443
# Episode: 442, score: 9.0, avg_score: 15.77, best_score: 15.88, epsilon: 0.1
#
# Game 444
# Episode: 443, score: 15.0, avg_score: 15.8, best_score: 15.88, epsilon: 0.1
#
# Game 445
# Episode: 444, score: 16.0, avg_score: 15.8, best_score: 15.88, epsilon: 0.1
#
# Game 446
# Episode: 445, score: 16.0, avg_score: 15.77, best_score: 15.88, epsilon: 0.1
#
# Game 447
# Episode: 446, score: 17.0, avg_score: 15.8, best_score: 15.88, epsilon: 0.1
#
# Game 448
# Episode: 447, score: 8.0, avg_score: 15.76, best_score: 15.88, epsilon: 0.1
#
# Game 449
# Episode: 448, score: 13.0, avg_score: 15.71, best_score: 15.88, epsilon: 0.1
#
# Game 450
# Episode: 449, score: 17.0, avg_score: 15.72, best_score: 15.88, epsilon: 0.1
#
# Game 451
# Episode: 450, score: 7.0, avg_score: 15.6, best_score: 15.88, epsilon: 0.1
#
# Game 452
# Episode: 451, score: 17.0, avg_score: 15.62, best_score: 15.88, epsilon: 0.1
#
# Game 453
# Episode: 452, score: 11.0, avg_score: 15.55, best_score: 15.88, epsilon: 0.1
#
# Game 454
# Episode: 453, score: 13.0, avg_score: 15.54, best_score: 15.88, epsilon: 0.1
#
# Game 455
# Episode: 454, score: 19.0, avg_score: 15.55, best_score: 15.88, epsilon: 0.1
#
# Game 456
# Episode: 455, score: 19.0, avg_score: 15.61, best_score: 15.88, epsilon: 0.1
#
# Game 457
# Episode: 456, score: 14.0, avg_score: 15.54, best_score: 15.88, epsilon: 0.1
#
# Game 458
# Episode: 457, score: 17.0, avg_score: 15.59, best_score: 15.88, epsilon: 0.1
#
# Game 459
# Episode: 458, score: 16.0, avg_score: 15.58, best_score: 15.88, epsilon: 0.1
#
# Game 460
# Episode: 459, score: 15.0, avg_score: 15.6, best_score: 15.88, epsilon: 0.1
#
# Game 461
# Episode: 460, score: 18.0, avg_score: 15.66, best_score: 15.88, epsilon: 0.1
#
# Game 462
# Episode: 461, score: 7.0, avg_score: 15.62, best_score: 15.88, epsilon: 0.1
#
# Game 463
# Episode: 462, score: 12.0, avg_score: 15.59, best_score: 15.88, epsilon: 0.1
#
# Game 464
# Episode: 463, score: 14.0, avg_score: 15.57, best_score: 15.88, epsilon: 0.1
#
# Game 465
# Episode: 464, score: 16.0, avg_score: 15.58, best_score: 15.88, epsilon: 0.1
#
# Game 466
# Episode: 465, score: 17.0, avg_score: 15.58, best_score: 15.88, epsilon: 0.1
#
# Game 467
# Episode: 466, score: 18.0, avg_score: 15.6, best_score: 15.88, epsilon: 0.1
#
# Game 468
# Episode: 467, score: 17.0, avg_score: 15.63, best_score: 15.88, epsilon: 0.1
#
# Game 469
# Episode: 468, score: 13.0, avg_score: 15.6, best_score: 15.88, epsilon: 0.1
#
# Game 470
# Episode: 469, score: 18.0, avg_score: 15.6, best_score: 15.88, epsilon: 0.1
#
# Game 471
# Episode: 470, score: 13.0, avg_score: 15.59, best_score: 15.88, epsilon: 0.1
#
# Game 472
# Episode: 471, score: 16.0, avg_score: 15.63, best_score: 15.88, epsilon: 0.1
#
# Game 473
# Episode: 472, score: 14.0, avg_score: 15.58, best_score: 15.88, epsilon: 0.1
#
# Game 474
# Episode: 473, score: 16.0, avg_score: 15.59, best_score: 15.88, epsilon: 0.1
#
# Game 475
# Episode: 474, score: 16.0, avg_score: 15.6, best_score: 15.88, epsilon: 0.1
#
# Game 476
# Episode: 475, score: 18.0, avg_score: 15.63, best_score: 15.88, epsilon: 0.1
#
# Game 477
# Episode: 476, score: 16.0, avg_score: 15.61, best_score: 15.88, epsilon: 0.1
#
# Game 478
# Episode: 477, score: 13.0, avg_score: 15.57, best_score: 15.88, epsilon: 0.1
#
# Game 479
# Episode: 478, score: 13.0, avg_score: 15.56, best_score: 15.88, epsilon: 0.1
#
# Game 480
# Episode: 479, score: 19.0, avg_score: 15.57, best_score: 15.88, epsilon: 0.1
#
# Game 481
# Episode: 480, score: 11.0, avg_score: 15.59, best_score: 15.88, epsilon: 0.1
#
# Game 482
# Episode: 481, score: 21.0, avg_score: 15.74, best_score: 15.88, epsilon: 0.1
#
# Game 483
# Episode: 482, score: 16.0, avg_score: 15.73, best_score: 15.88, epsilon: 0.1
#
# Game 484
# Episode: 483, score: 11.0, avg_score: 15.68, best_score: 15.88, epsilon: 0.1
#
# Game 485
# Episode: 484, score: 16.0, avg_score: 15.7, best_score: 15.88, epsilon: 0.1
#
# Game 486
# Episode: 485, score: 19.0, avg_score: 15.77, best_score: 15.88, epsilon: 0.1
#
# Game 487
# Episode: 486, score: 18.0, avg_score: 15.78, best_score: 15.88, epsilon: 0.1
#
# Game 488
# Episode: 487, score: 16.0, avg_score: 15.76, best_score: 15.88, epsilon: 0.1
#
# Game 489
# Episode: 488, score: 12.0, avg_score: 15.74, best_score: 15.88, epsilon: 0.1
#
# Game 490
# Episode: 489, score: 17.0, avg_score: 15.73, best_score: 15.88, epsilon: 0.1
#
# Game 491
# Episode: 490, score: 15.0, avg_score: 15.73, best_score: 15.88, epsilon: 0.1
#
# Game 492
# Episode: 491, score: 15.0, avg_score: 15.73, best_score: 15.88, epsilon: 0.1
#
# Game 493
# Episode: 492, score: 18.0, avg_score: 15.79, best_score: 15.88, epsilon: 0.1
#
# Game 494
# Episode: 493, score: 17.0, avg_score: 15.78, best_score: 15.88, epsilon: 0.1
#
# Game 495
# Episode: 494, score: 13.0, avg_score: 15.73, best_score: 15.88, epsilon: 0.1
#
# Game 496
# Episode: 495, score: 16.0, avg_score: 15.71, best_score: 15.88, epsilon: 0.1
#
# Game 497
# Episode: 496, score: 20.0, avg_score: 15.72, best_score: 15.88, epsilon: 0.1
#
# Game 498
# Episode: 497, score: 20.0, avg_score: 15.73, best_score: 15.88, epsilon: 0.1
#
# Game 499
# Episode: 498, score: 16.0, avg_score: 15.76, best_score: 15.88, epsilon: 0.1
#
# Game 500
# Episode: 499, score: 11.0, avg_score: 15.69, best_score: 15.88, epsilon: 0.1
