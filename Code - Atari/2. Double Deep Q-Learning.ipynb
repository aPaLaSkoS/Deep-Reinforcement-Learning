# %% [markdown]
# # Imports + Installs

# %%
# !pip install "gym[atari, accept-rom-license]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym[accept-rom-license,atari] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (1.22.4)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (2.2.1)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (0.4.2)
# Requirement already satisfied: ale-py~=0.7.5 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (0.7.5)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.7.5->gym[accept-rom-license,atari]) (5.12.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (4.65.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (8.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.27.1)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (0.6.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (3.4)

# %%
import gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import collections
import cv2
import os
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import warnings
from google.colab import files
warnings.filterwarnings("ignore")

# %% [markdown]
# # Classes + Helpers

# %% [markdown]
# ## Environment

# %%
class RepeatActionAndMaxFrame(gym.Wrapper):
  def __init__(self, env=None, repeat=4, clip_rewards=False, no_ops=0, fire_first=False):
    super(RepeatActionAndMaxFrame, self).__init__(env)
    self.repeat = repeat
    self.shape = env.observation_space.low.shape
    self.frame_buffer = np.zeros_like((2, self.shape))
    self.clip_rewards = clip_rewards 
    self.no_ops = no_ops
    self.fire_first = fire_first
  
  def step(self, action):
    total_reward = 0.0
    done = False
    for i in range(self.repeat):
      obs, reward, done, info = self.env.step(action)
      if self.clip_rewards:
        reward = np.clip(np.array([reward]), -1, 1)[0]
      total_reward += reward
      idx = i % 2
      self.frame_buffer[idx] = obs
      if done:
        break

    max_frame = np.maximum(self.frame_buffer[0], self.frame_buffer[1])
    return max_frame, total_reward, done, info
  
  def reset(self):
    obs = self.env.reset()
    no_ops = np.random.randint(self.no_ops) + 1 if self.no_ops > 0 else 0
    for _ in range(no_ops):
      _, _, done, _ = self.env.step(0)
      if done:
        self.env.reset()
    if self.fire_first:
      assert self.env.unwrapped.get_action_meanings()[1] == 'FIRE'
      obs, _, _, _ = self.env.step(1)

    self.frame_buffer = np.zeros_like((2, self.shape))
    self.frame_buffer[0] = obs
    return obs


class PreprocessFrame(gym.ObservationWrapper):
  def __init__(self, shape, env=None):
    super(PreprocessFrame, self).__init__(env)
    self.shape = (shape[2], shape[0], shape[1])
    self.observation_space = gym.spaces.Box(low=0.0, high=1.0,
                                            shape=self.shape,
                                            dtype=np.float32)
  
  def observation(self, obs):
    new_frame = cv2.cvtColor(obs, cv2.COLOR_BGR2GRAY)
    resized_screen = cv2.resize(new_frame, 
                                self.shape[1:],
                                interpolation=cv2.INTER_AREA)
    new_obs = np.array(resized_screen, dtype=np.float16).reshape(self.shape)
    new_obs /= 255.0

    return new_obs


class StackFrames(gym.ObservationWrapper):
  def __init__(self, env, repeat):
    super(StackFrames, self).__init__(env)
    self.observation_space = gym.spaces.Box(
        env.observation_space.low.repeat(repeat, axis=0),
        env.observation_space.high.repeat(repeat, axis=0)
    )
    self.stack = collections.deque(maxlen=repeat)

  def reset(self):
    self.stack.clear()
    observation = self.env.reset()
    for _ in range(self.stack.maxlen):
      self.stack.append(observation)
    
    return np.array(self.stack).reshape(self.observation_space.low.shape)
  
  def observation(self, observation):
    self.stack.append(observation)
    return np.array(self.stack).reshape(self.observation_space.low.shape)


def make_env(env_name, shape=(84, 84, 1), repeat=4, clip_rewards=False, no_ops=0, fire_first=False):
  env = gym.make(env_name)
  env = RepeatActionAndMaxFrame(env, repeat, clip_rewards, no_ops, fire_first)
  env = PreprocessFrame(shape, env)
  env = StackFrames(env, repeat)
  return env

# %% [markdown]
# ## Agent

# %%
class ReplayBuffer():
  def __init__(self, max_size, input_shape, n_actions):
    self.mem_size = max_size
    self.mem_counter = 0
    self.state_memory = np.zeros(
        (self.mem_size, *input_shape),
        dtype=np.float32
    )
    self.new_state_memory = np.zeros(
        (self.mem_size, *input_shape),
        dtype=np.float32
    )
    self.action_memory = np.zeros(self.mem_size, dtype=np.int64)
    self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
    self.terminal_memory = np.zeros(self.mem_size, dtype=np.uint8)
  
  def store_transition(self, state, action, reward, state_, done):
    index = self.mem_counter % self.mem_size
    self.state_memory[index] = state
    self.action_memory[index] = action
    self.reward_memory[index] = reward
    self.new_state_memory[index] = state_
    self.terminal_memory[index] = done
    self.mem_counter += 1
  
  def sample_buffer(self, batch_size):
    max_mem = min(self.mem_counter, self.mem_size)
    batch = np.random.choice(max_mem, batch_size, replace=True)
    states = self.state_memory[batch]
    actions = self.action_memory[batch]
    rewards = self.reward_memory[batch]
    states_ = self.new_state_memory[batch]
    dones = self.terminal_memory[batch]

    return states, actions, rewards, states_, dones


class DeepQNetwork(nn.Module):
  def __init__(self, lr, n_actions, name, input_dims, chkpt_dir):
    super(DeepQNetwork, self).__init__()
    self.checkpoint_dir = chkpt_dir
    self.checkpoint_file = os.path.join(self.checkpoint_dir, name)
    if not os.path.exists(self.checkpoint_dir):
      os.makedirs(self.checkpoint_dir)

    self.conv1 = nn.Conv2d(input_dims[0], 32, 8, stride=4)
    self.conv2 = nn.Conv2d(32, 64, 4, stride=2)
    self.conv3 = nn.Conv2d(64, 64, 3, stride=1)

    fc_input_dims = self.calculate_conv_output_dims(input_dims)
    
    self.fc1 = nn.Linear(fc_input_dims, 512)
    self.fc2 = nn.Linear(512, n_actions)

    self.optimizer = optim.RMSprop(self.parameters(), lr=lr)
    self.loss = nn.MSELoss()
    self.device = T.device('cuda' if T.cuda.is_available() else 'cpu')
    self.to(self.device)

  def calculate_conv_output_dims(self, input_dims):
    state = T.zeros(1, *input_dims)
    dims = self.conv1(state)
    dims = self.conv2(dims)
    dims = self.conv3(dims)
    return int(np.prod(dims.size()))

  def forward(self, state):
    state = F.relu(self.conv1(state))
    state = F.relu(self.conv2(state))
    state = F.relu(self.conv3(state))
    # conv3 shape is: batch_size x n_filters x H x W
    state = state.view(state.size()[0], -1)
    state = F.relu(self.fc1(state))
    actions = self.fc2(state)

    return actions

  def save_checkpoint(self):
    print('... saving checkpoint ...')
    T.save(self.state_dict(), self.checkpoint_file)
  
  def load_checkpoint(self):
    print('... loading checkpoint ...')
    self.load_state_dict(T.load(self.checkpoint_file))


class DDQNAgent():
  def __init__(self, gamma, epsilon, lr, n_actions, input_dims,
               mem_size, batch_size, eps_min=0.01, eps_dec=5e-7, 
               replace=1000, algo=None, env_name=None, chkpt_dir='tmp/dqn'):
    self.gamma = gamma
    self.epsilon = epsilon
    self.lr = lr
    self.n_actions = n_actions
    self.input_dims = input_dims
    self.batch_size = batch_size
    self.eps_min = eps_min
    self.eps_dec = eps_dec
    self.replace_target_counter = replace
    self.algo = algo
    self.env_name = env_name
    self.chkpt_dir = chkpt_dir
    self.action_space = [i for i in range(self.n_actions)]
    self.learn_step_counter = 0

    self.memory = ReplayBuffer(mem_size, input_dims, n_actions)

    self.Q_eval = DeepQNetwork(self.lr, self.n_actions,
                               input_dims=self.input_dims,
                               name=self.env_name + '_' + self.algo + '_Q_eval.pth',
                               chkpt_dir=self.chkpt_dir)

    self.Q_next = DeepQNetwork(self.lr, self.n_actions,
                               input_dims=self.input_dims,
                               name=self.env_name + '_' + self.algo + '_Q_next.pth',
                               chkpt_dir=self.chkpt_dir)   
  
  def choose_action(self, observation):
    if np.random.random() > self.epsilon:
      state = T.tensor([observation], dtype=T.float).to(self.Q_eval.device)
      actions = self.Q_eval.forward(state)
      action = T.argmax(actions).item()
    else:
      action = np.random.choice(self.action_space)
    return action
  
  def store_transition(self, state, action, reward, state_, done):
    self.memory.store_transition(state, action, reward, state_, done)
  
  def sample_memory(self):
    state, action, reward, new_state, done = self.memory.sample_buffer(self.batch_size)
    states = T.tensor(state).to(self.Q_eval.device)
    actions = T.tensor(action).to(self.Q_eval.device)
    rewards = T.tensor(reward).to(self.Q_eval.device)
    states_ = T.tensor(new_state).to(self.Q_eval.device)
    dones = T.tensor(done).to(self.Q_eval.device)

    return states, actions, rewards, states_, dones
  
  def replace_target_network(self):
    if self.learn_step_counter % self.replace_target_counter == 0:
      self.Q_next.load_state_dict(self.Q_eval.state_dict())
  
  def decrement_epsilon(self):
    self.epsilon = self.epsilon - self.eps_dec if self.epsilon > self.eps_min else self.eps_min
  
  def save_models(self):
    self.Q_eval.save_checkpoint()
    self.Q_next.save_checkpoint()

  def load_models(self):
    self.Q_eval.load_checkpoint()
    self.Q_next.load_checkpoint()
  
  def learn(self):
    if self.memory.mem_counter < self.batch_size:
      return 
    
    self.Q_eval.optimizer.zero_grad()

    self.replace_target_network()
    states, actions, rewards, states_, dones = self.sample_memory()

    indices = np.arange(self.batch_size)

    # ================== CHANGES START HERE ... =====================
    Q_pred = self.Q_eval.forward(states)[indices, actions]
    Q_next = self.Q_next.forward(states_)
    Q_eval = self.Q_eval.forward(states_)
    max_actions = T.argmax(Q_eval, dim=1)
    
    # where the episodes are reach a terminal state (done=1),
    # there target must be equal to r
    Q_next[dones] = 0.0
    Q_target = rewards + self.gamma * Q_next[indices, max_actions]
    # ================== CHANGES END HERE ... =======================

    loss = self.Q_eval.loss(Q_target, Q_pred).to(self.Q_eval.device)
    loss.backward()
    self.Q_eval.optimizer.step()
    self.learn_step_counter += 1

    self.decrement_epsilon()

# %% [markdown]
# ## Other

# %%
def  plot_learning_curve(x, scores, epsilons, lines=None):
  fig = plt.figure(figsize=(30, 10))
  ax = fig.add_subplot(111, label='1')
  ax2 = fig.add_subplot(111, label='2', frame_on=False)

  ax.plot(x, epsilons, color='C0')
  ax.set_xlabel("Training steps", color="C0")
  ax.set_ylabel("Epsilon", color="C0")
  ax.tick_params(axis='x', colors="C0")
  ax.tick_params(axis='y', colors='C0')

  N = len(scores)
  running_avg = np.empty(N)
  for t in range(N):
    running_avg[t] = np.mean(scores[max(0, t-20):(t+1)])
  
  ax2.scatter(x, running_avg, color="C1")
  ax2.axes.get_xaxis().set_visible(False)
  ax2.yaxis.tick_right()
  ax2.set_ylabel('Score', color="C1")
  ax2.yaxis.set_label_position('right')
  ax2.tick_params(axis='y', colors="C1")

  if lines is not None:
    for line in lines:
      plt.axvline(x=line)
  
  # plt.savefig(filename)

# %% [markdown]
# # MAIN

# %%
# !rm -rf './models'
env = make_env('PongNoFrameskip-v4')

best_score = -np.inf
load_checkpoint = False
n_games = 500

agent = DDQNAgent(gamma=0.99, epsilon=1.0, lr=1e-4,
                  input_dims=(env.observation_space.shape),
                  n_actions=env.action_space.n, mem_size=20000, 
                  eps_min=0.1, batch_size=32, replace=1000, 
                  eps_dec=1e-5, chkpt_dir='models/', 
                  algo='DDQNAgent', env_name='PongNoFrameskip-v4')

if load_checkpoint:
  agent.load_models()

# file_name = agent.algo +'_' + agent.env_name + '_lr' + str(agent.lr) + '_' + str(n_games) + '_games'
# figure_file = 'plots/' + file_name + '.png'

n_steps = 0
scores, eps_history, steps_array = [], [], []

for i in range(n_games):
  print(f"\nGame {i+1}")
  done = False
  score = 0
  observation = env.reset()

  while not done:
    action = agent.choose_action(observation)
    observation_, reward, done, info = env.step(action)
    score += reward

    if not load_checkpoint:
      agent.store_transition(observation, action, reward, observation_, int(done))
      agent.learn()
    
    observation = observation_
    n_steps += 1

  scores.append(score)
  steps_array.append(n_steps)

  avg_score = np.mean(scores[-100:])
  print(f"Episode: {i}, score: {score}, avg_score: {avg_score}, best_score: {best_score}, epsilon: {agent.epsilon}")

  if avg_score > best_score:
    if not load_checkpoint:
      agent.save_models()
    best_score = avg_score
  
  eps_history.append(agent.epsilon)

plot_learning_curve(steps_array, scores, eps_history)

df = pd.DataFrame(
    {
        'steps_array': steps_array, 
        'scores': scores, 
        'eps_history': eps_history
    }
)

filename = 'Atari_DDQL_results.csv' 
df.to_csv(filename)
files.download(filename)
# Out:
# Game 1
# Episode: 0, score: -21.0, avg_score: -21.0, best_score: -inf, epsilon: 0.9913100000000395
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 2
# Episode: 1, score: -20.0, avg_score: -20.5, best_score: -21.0, epsilon: 0.9820000000000819
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 3
# Episode: 2, score: -21.0, avg_score: -20.666666666666668, best_score: -20.5, epsilon: 0.9737300000001196
#
# Game 4
# Episode: 3, score: -19.0, avg_score: -20.25, best_score: -20.5, epsilon: 0.9634100000001665
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 5
# Episode: 4, score: -19.0, avg_score: -20.0, best_score: -20.25, epsilon: 0.9515900000002203
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 6
# Episode: 5, score: -21.0, avg_score: -20.166666666666668, best_score: -20.0, epsilon: 0.9439400000002551
#
# Game 7
# Episode: 6, score: -21.0, avg_score: -20.285714285714285, best_score: -20.0, epsilon: 0.9339400000003006
#
# Game 8
# Episode: 7, score: -21.0, avg_score: -20.375, best_score: -20.0, epsilon: 0.9256900000003382
#
# Game 9
# Episode: 8, score: -20.0, avg_score: -20.333333333333332, best_score: -20.0, epsilon: 0.915190000000386
#
# Game 10
# Episode: 9, score: -21.0, avg_score: -20.4, best_score: -20.0, epsilon: 0.9056000000004296
#
# Game 11
# Episode: 10, score: -21.0, avg_score: -20.454545454545453, best_score: -20.0, epsilon: 0.8974800000004666
#
# Game 12
# Episode: 11, score: -21.0, avg_score: -20.5, best_score: -20.0, epsilon: 0.8874000000005124
#
# Game 13
# Episode: 12, score: -20.0, avg_score: -20.46153846153846, best_score: -20.0, epsilon: 0.8772200000005588
#
# Game 14
# Episode: 13, score: -20.0, avg_score: -20.428571428571427, best_score: -20.0, epsilon: 0.8674400000006033
#
# Game 15
# Episode: 14, score: -18.0, avg_score: -20.266666666666666, best_score: -20.0, epsilon: 0.8565500000006528
#
# Game 16
# Episode: 15, score: -19.0, avg_score: -20.1875, best_score: -20.0, epsilon: 0.8466000000006981
#
# Game 17
# Episode: 16, score: -20.0, avg_score: -20.176470588235293, best_score: -20.0, epsilon: 0.8378200000007381
#
# Game 18
# Episode: 17, score: -19.0, avg_score: -20.11111111111111, best_score: -20.0, epsilon: 0.8278500000007835
#
# Game 19
# Episode: 18, score: -20.0, avg_score: -20.105263157894736, best_score: -20.0, epsilon: 0.8170500000008326
#
# Game 20
# Episode: 19, score: -21.0, avg_score: -20.15, best_score: -20.0, epsilon: 0.808620000000871
#
# Game 21
# Episode: 20, score: -18.0, avg_score: -20.047619047619047, best_score: -20.0, epsilon: 0.7986400000009164
#
# Game 22
# Episode: 21, score: -20.0, avg_score: -20.045454545454547, best_score: -20.0, epsilon: 0.7885500000009623
#
# Game 23
# Episode: 22, score: -21.0, avg_score: -20.08695652173913, best_score: -20.0, epsilon: 0.7786000000010076
#
# Game 24
# Episode: 23, score: -21.0, avg_score: -20.125, best_score: -20.0, epsilon: 0.7698300000010475
#
# Game 25
# Episode: 24, score: -19.0, avg_score: -20.08, best_score: -20.0, epsilon: 0.7582300000011003
#
# Game 26
# Episode: 25, score: -20.0, avg_score: -20.076923076923077, best_score: -20.0, epsilon: 0.7485800000011442
#
# Game 27
# Episode: 26, score: -19.0, avg_score: -20.037037037037038, best_score: -20.0, epsilon: 0.7365200000011991
#
# Game 28
# Episode: 27, score: -18.0, avg_score: -19.964285714285715, best_score: -20.0, epsilon: 0.7242000000012552
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 29
# Episode: 28, score: -20.0, avg_score: -19.96551724137931, best_score: -19.964285714285715, epsilon: 0.7121900000013098
#
# Game 30
# Episode: 29, score: -21.0, avg_score: -20.0, best_score: -19.964285714285715, epsilon: 0.6995600000013673
#
# Game 31
# Episode: 30, score: -20.0, avg_score: -20.0, best_score: -19.964285714285715, epsilon: 0.6894600000014133
#
# Game 32
# Episode: 31, score: -20.0, avg_score: -20.0, best_score: -19.964285714285715, epsilon: 0.6762600000014733
#
# Game 33
# Episode: 32, score: -17.0, avg_score: -19.90909090909091, best_score: -19.964285714285715, epsilon: 0.6621300000015377
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 34
# Episode: 33, score: -15.0, avg_score: -19.764705882352942, best_score: -19.90909090909091, epsilon: 0.6465400000016086
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 35
# Episode: 34, score: -20.0, avg_score: -19.771428571428572, best_score: -19.764705882352942, epsilon: 0.6339800000016658
#
# Game 36
# Episode: 35, score: -16.0, avg_score: -19.666666666666668, best_score: -19.764705882352942, epsilon: 0.6196800000017308
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game
epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 248
# Episode: 247, score: 11.0, avg_score: 13.65, best_score: 13.68, epsilon: 0.1
#
# Game 249
# Episode: 248, score: 14.0, avg_score: 13.68, best_score: 13.68, epsilon: 0.1
#
# Game 250
# Episode: 249, score: 17.0, avg_score: 13.68, best_score: 13.68, epsilon: 0.1
#
# Game 251
# Episode: 250, score: 13.0, avg_score: 13.68, best_score: 13.68, epsilon: 0.1
#
# Game 252
# Episode: 251, score: 16.0, avg_score: 13.7, best_score: 13.68, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 253
# Episode: 252, score: 17.0, avg_score: 13.7, best_score: 13.7, epsilon: 0.1
#
# Game 254
# Episode: 253, score: 17.0, avg_score: 13.7, best_score: 13.7, epsilon: 0.1
#
# Game 255
# Episode: 254, score: 14.0, avg_score: 13.71, best_score: 13.7, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 256
# Episode: 255, score: 18.0, avg_score: 13.75, best_score: 13.71, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 257
# Episode: 256, score: 9.0, avg_score: 13.68, best_score: 13.75, epsilon: 0.1
#
# Game 258
# Episode: 257, score: 17.0, avg_score: 13.73, best_score: 13.75, epsilon: 0.1
#
# Game 259
# Episode: 258, score: 16.0, avg_score: 13.81, best_score: 13.75, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 260
# Episode: 259, score: 14.0, avg_score: 13.81, best_score: 13.81, epsilon: 0.1
#
# Game 261
# Episode: 260, score: 16.0, avg_score: 13.83, best_score: 13.81, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 262
# Episode: 261, score: 11.0, avg_score: 13.77, best_score: 13.83, epsilon: 0.1
#
# Game 263
# Episode: 262, score: 17.0, avg_score: 13.83, best_score: 13.83, epsilon: 0.1
#
# Game 264
# Episode: 263, score: 12.0, avg_score: 13.79, best_score: 13.83, epsilon: 0.1
#
# Game 265
# Episode: 264, score: 14.0, avg_score: 13.77, best_score: 13.83, epsilon: 0.1
#
# Game 266
# Episode: 265, score: 10.0, avg_score: 13.76, best_score: 13.83, epsilon: 0.1
#
# Game 267
# Episode: 266, score: 12.0, avg_score: 13.78, best_score: 13.83, epsilon: 0.1
#
# Game 268
# Episode: 267, score: 17.0, avg_score: 13.79, best_score: 13.83, epsilon: 0.1
#
# Game 269
# Episode: 268, score: 15.0, avg_score: 13.86, best_score: 13.83, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 270
# Episode: 269, score: 20.0, avg_score: 13.88, best_score: 13.86, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 271
# Episode: 270, score: 16.0, avg_score: 13.91, best_score: 13.88, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 272
# Episode: 271, score: 18.0, avg_score: 13.96, best_score: 13.91, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 273
# Episode: 272, score: 17.0, avg_score: 13.98, best_score: 13.96, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 274
# Episode: 273, score: 18.0, avg_score: 14.0, best_score: 13.98, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 275
# Episode: 274, score: 16.0, avg_score: 14.04, best_score: 14.0, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 276
# Episode: 275, score: 18.0, avg_score: 14.07, best_score: 14.04, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 277
# Episode: 276, score: 19.0, avg_score: 14.14, best_score: 14.07, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 278
# Episode: 277, score: 15.0, avg_score: 14.14, best_score: 14.14, epsilon: 0.1
#
# Game 279
# Episode: 278, score: 17.0, avg_score: 14.15, best_score: 14.14, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 280
# Episode: 279, score: 18.0, avg_score: 14.28, best_score: 14.15, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 281
# Episode: 280, score: 16.0, avg_score: 14.3, best_score: 14.28, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 282
# Episode: 281, score: 16.0, avg_score: 14.37, best_score: 14.3, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 283
# Episode: 282, score: 16.0, avg_score: 14.41, best_score: 14.37, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 284
# Episode: 283, score: 13.0, avg_score: 14.45, best_score: 14.41, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 285
# Episode: 284, score: 11.0, avg_score: 14.43, best_score: 14.45, epsilon: 0.1
#
# Game 286
# Episode: 285, score: 11.0, avg_score: 14.41, best_score: 14.45, epsilon: 0.1
#
# Game 287
# Episode: 286, score: 15.0, avg_score: 14.42, best_score: 14.45, epsilon: 0.1
#
# Game 288
# Episode: 287, score: 14.0, avg_score: 14.44, best_score: 14.45, epsilon: 0.1
#
# Game 289
# Episode: 288, score: 15.0, avg_score: 14.46, best_score: 14.45, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 290
# Episode: 289, score: 16.0, avg_score: 14.47, best_score: 14.46, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 291
# Episode: 290, score: 15.0, avg_score: 14.45, best_score: 14.47, epsilon: 0.1
#
# Game 292
# Episode: 291, score: 19.0, avg_score: 14.51, best_score: 14.47, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 293
# Episode: 292, score: 13.0, avg_score: 14.54, best_score: 14.51, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 294
# Episode: 293, score: 18.0, avg_score: 14.57, best_score: 14.54, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 295
# Episode: 294, score: 14.0, avg_score: 14.55, best_score: 14.57, epsilon: 0.1
#
# Game 296
# Episode: 295, score: 18.0, avg_score: 14.67, best_score: 14.57, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 297
# Episode: 296, score: 14.0, avg_score: 14.69, best_score: 14.67, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 298
# Episode: 297, score: 19.0, avg_score: 14.73, best_score: 14.69, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 299
# Episode: 298, score: 13.0, avg_score: 14.71, best_score: 14.73, epsilon: 0.1
#
# Game 300
# Episode: 299, score: 18.0, avg_score: 14.75, best_score: 14.73, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 301
# Episode: 300, score: 11.0, avg_score: 14.83, best_score: 14.75, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 302
# Episode: 301, score: 14.0, avg_score: 14.87, best_score: 14.83, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 303
# Episode: 302, score: 13.0, avg_score: 14.87, best_score: 14.87, epsilon: 0.1
#
# Game 304
# Episode: 303, score: 15.0, avg_score: 14.87, best_score: 14.87, epsilon: 0.1
#
# Game 305
# Episode: 304, score: 21.0, avg_score: 14.95, best_score: 14.87, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 306
# Episode: 305, score: 15.0, avg_score: 14.92, best_score: 14.95, epsilon: 0.1
#
# Game 307
# Episode: 306, score: 14.0, avg_score: 14.88, best_score: 14.95, epsilon: 0.1
#
# Game 308
# Episode: 307, score: 14.0, avg_score: 14.86, best_score: 14.95, epsilon: 0.1
#
# Game 309
# Episode: 308, score: 19.0, avg_score: 14.91, best_score: 14.95, epsilon: 0.1
#
# Game 310
# Episode: 309, score: 16.0, avg_score: 14.9, best_score: 14.95, epsilon: 0.1
#
# Game 311
# Episode: 310, score: 14.0, avg_score: 14.86, best_score: 14.95, epsilon: 0.1
#
# Game 312
# Episode: 311, score: 16.0, avg_score: 14.89, best_score: 14.95, epsilon: 0.1
#
# Game 313
# Episode: 312, score: 11.0, avg_score: 14.84, best_score: 14.95, epsilon: 0.1
#
# Game 314
# Episode: 313, score: 17.0, avg_score: 14.87, best_score: 14.95, epsilon: 0.1
#
# Game 315
# Episode: 314, score: 13.0, avg_score: 14.83, best_score: 14.95, epsilon: 0.1
#
# Game 316
# Episode: 315, score: 18.0, avg_score: 14.88, best_score: 14.95, epsilon: 0.1
#
# Game 317
# Episode: 316, score: 19.0, avg_score: 14.91, best_score: 14.95, epsilon: 0.1
#
# Game 318
# Episode: 317, score: 20.0, avg_score: 14.94, best_score: 14.95, epsilon: 0.1
#
# Game 319
# Episode: 318, score: 10.0, avg_score: 14.85, best_score: 14.95, epsilon: 0.1
#
# Game 320
# Episode: 319, score: 14.0, avg_score: 14.85, best_score: 14.95, epsilon: 0.1
#
# Game 321
# Episode: 320, score: 18.0, avg_score: 14.94, best_score: 14.95, epsilon: 0.1
#
# Game 322
# Episode: 321, score: 15.0, avg_score: 14.97, best_score: 14.95, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 323
# Episode: 322, score: 16.0, avg_score: 14.99, best_score: 14.97, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 324
# Episode: 323, score: 18.0, avg_score: 15.01, best_score: 14.99, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 325
# Episode: 324, score: 15.0, avg_score: 15.11, best_score: 15.01, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 326
# Episode: 325, score: 14.0, avg_score: 15.12, best_score: 15.11, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 327
# Episode: 326, score: 15.0, avg_score: 15.09, best_score: 15.12, epsilon: 0.1
#
# Game 328
# Episode: 327, score: 16.0, avg_score: 15.13, best_score: 15.12, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 329
# Episode: 328, score: 13.0, avg_score: 15.13, best_score: 15.13, epsilon: 0.1
#
# Game 330
# Episode: 329, score: 16.0, avg_score: 15.1, best_score: 15.13, epsilon: 0.1
#
# Game 331
# Episode: 330, score: 15.0, avg_score: 15.2, best_score: 15.13, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 332
# Episode: 331, score: 16.0, avg_score: 15.23, best_score: 15.2, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 333
# Episode: 332, score: 16.0, avg_score: 15.21, best_score: 15.23, epsilon: 0.1
#
# Game 334
# Episode: 333, score: 17.0, avg_score: 15.24, best_score: 15.23, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 335
# Episode: 334, score: 14.0, avg_score: 15.29, best_score: 15.24, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 336
# Episode: 335, score: 19.0, avg_score: 15.33, best_score: 15.29, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 337
# Episode: 336, score: 13.0, avg_score: 15.33, best_score: 15.33, epsilon: 0.1
#
# Game 338
# Episode: 337, score: 15.0, avg_score: 15.34, best_score: 15.33, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 339
# Episode: 338, score: 15.0, avg_score: 15.33, best_score: 15.34, epsilon: 0.1
#
# Game 340
# Episode: 339, score: 15.0, avg_score: 15.35, best_score: 15.34, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 341
# Episode: 340, score: 17.0, avg_score: 15.38, best_score: 15.35, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 342
# Episode: 341, score: 14.0, avg_score: 15.37, best_score: 15.38, epsilon: 0.1
#
# Game 343
# Episode: 342, score: 6.0, avg_score: 15.27, best_score: 15.38, epsilon: 0.1
#
# Game 344
# Episode: 343, score: 18.0, avg_score: 15.33, best_score: 15.38, epsilon: 0.1
#
# Game 345
# Episode: 344, score: 12.0, avg_score: 15.29, best_score: 15.38, epsilon: 0.1
#
# Game 346
# Episode: 345, score: 17.0, avg_score: 15.31, best_score: 15.38, epsilon: 0.1
#
# Game 347
# Episode: 346, score: 19.0, avg_score: 15.31, best_score: 15.38, epsilon: 0.1
#
# Game 348
# Episode: 347, score: 16.0, avg_score: 15.36, best_score: 15.38, epsilon: 0.1
#
# Game 349
# Episode: 348, score: 14.0, avg_score: 15.36, best_score: 15.38, epsilon: 0.1
#
# Game 350
# Episode: 349, score: 14.0, avg_score: 15.33, best_score: 15.38, epsilon: 0.1
#
# Game 351
# Episode: 350, score: 13.0, avg_score: 15.33, best_score: 15.38, epsilon: 0.1
#
# Game 352
# Episode: 351, score: 16.0, avg_score: 15.33, best_score: 15.38, epsilon: 0.1
#
# Game 353
# Episode: 352, score: 17.0, avg_score: 15.33, best_score: 15.38, epsilon: 0.1
#
# Game 354
# Episode: 353, score: 15.0, avg_score: 15.31, best_score: 15.38, epsilon: 0.1
#
# Game 355
# Episode: 354, score: 17.0, avg_score: 15.34, best_score: 15.38, epsilon: 0.1
#
# Game 356
# Episode: 355, score: 21.0, avg_score: 15.37, best_score: 15.38, epsilon: 0.1
#
# Game 357
# Episode: 356, score: 14.0, avg_score: 15.42, best_score: 15.38, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 358
# Episode: 357, score: 19.0, avg_score: 15.44, best_score: 15.42, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 359
# Episode: 358, score: 15.0, avg_score: 15.43, best_score: 15.44, epsilon: 0.1
#
# Game 360
# Episode: 359, score: 17.0, avg_score: 15.46, best_score: 15.44, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 361
# Episode: 360, score: 14.0, avg_score: 15.44, best_score: 15.46, epsilon: 0.1
#
# Game 362
# Episode: 361, score: 16.0, avg_score: 15.49, best_score: 15.46, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 363
# Episode: 362, score: 17.0, avg_score: 15.49, best_score: 15.49, epsilon: 0.1
#
# Game 364
# Episode: 363, score: 10.0, avg_score: 15.47, best_score: 15.49, epsilon: 0.1
#
# Game 365
# Episode: 364, score: 17.0, avg_score: 15.5, best_score: 15.49, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 366
# Episode: 365, score: 15.0, avg_score: 15.55, best_score: 15.5, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 367
# Episode: 366, score: 21.0, avg_score: 15.64, best_score: 15.55, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 368
# Episode: 367, score: 14.0, avg_score: 15.61, best_score: 15.64, epsilon: 0.1
#
# Game 369
# Episode: 368, score: 17.0, avg_score: 15.63, best_score: 15.64, epsilon: 0.1
#
# Game 370
# Episode: 369, score: 14.0, avg_score: 15.57, best_score: 15.64, epsilon: 0.1
#
# Game 371
# Episode: 370, score: 13.0, avg_score: 15.54, best_score: 15.64, epsilon: 0.1
#
# Game 372
# Episode: 371, score: 17.0, avg_score: 15.53, best_score: 15.64, epsilon: 0.1
#
# Game 373
# Episode: 372, score: 15.0, avg_score: 15.51, best_score: 15.64, epsilon: 0.1
#
# Game 374
# Episode: 373, score: 16.0, avg_score: 15.49, best_score: 15.64, epsilon: 0.1
#
# Game 375
# Episode: 374, score: 17.0, avg_score: 15.5, best_score: 15.64, epsilon: 0.1
#
# Game 376
# Episode: 375, score: 9.0, avg_score: 15.41, best_score: 15.64, epsilon: 0.1
#
# Game 377
# Episode: 376, score: 19.0, avg_score: 15.41, best_score: 15.64, epsilon: 0.1
#
# Game 378
# Episode: 377, score: 17.0, avg_score: 15.43, best_score: 15.64, epsilon: 0.1
#
# Game 379
# Episode: 378, score: 17.0, avg_score: 15.43, best_score: 15.64, epsilon: 0.1
#
# Game 380
# Episode: 379, score: 14.0, avg_score: 15.39, best_score: 15.64, epsilon: 0.1
#
# Game 381
# Episode: 380, score: 19.0, avg_score: 15.42, best_score: 15.64, epsilon: 0.1
#
# Game 382
# Episode: 381, score: 16.0, avg_score: 15.42, best_score: 15.64, epsilon: 0.1
#
# Game 383
# Episode: 382, score: 15.0, avg_score: 15.41, best_score: 15.64, epsilon: 0.1
#
# Game 384
# Episode: 383, score: 17.0, avg_score: 15.45, best_score: 15.64, epsilon: 0.1
#
# Game 385
# Episode: 384, score: 16.0, avg_score: 15.5, best_score: 15.64, epsilon: 0.1
#
# Game 386
# Episode: 385, score: 19.0, avg_score: 15.58, best_score: 15.64, epsilon: 0.1
#
# Game 387
# Episode: 386, score: 13.0, avg_score: 15.56, best_score: 15.64, epsilon: 0.1
#
# Game 388
# Episode: 387, score: 17.0, avg_score: 15.59, best_score: 15.64, epsilon: 0.1
#
# Game 389
# Episode: 388, score: 17.0, avg_score: 15.61, best_score: 15.64, epsilon: 0.1
#
# Game 390
# Episode: 389, score: 9.0, avg_score: 15.54, best_score: 15.64, epsilon: 0.1
#
# Game 391
# Episode: 390, score: 15.0, avg_score: 15.54, best_score: 15.64, epsilon: 0.1
#
# Game 392
# Episode: 391, score: 15.0, avg_score: 15.5, best_score: 15.64, epsilon: 0.1
#
# Game 393
# Episode: 392, score: 16.0, avg_score: 15.53, best_score: 15.64, epsilon: 0.1
#
# Game 394
# Episode: 393, score: 10.0, avg_score: 15.45, best_score: 15.64, epsilon: 0.1
#
# Game 395
# Episode: 394, score: 19.0, avg_score: 15.5, best_score: 15.64, epsilon: 0.1
#
# Game 396
# Episode: 395, score: 19.0, avg_score: 15.51, best_score: 15.64, epsilon: 0.1
#
# Game 397
# Episode: 396, score: 19.0, avg_score: 15.56, best_score: 15.64, epsilon: 0.1
#
# Game 398
# Episode: 397, score: 10.0, avg_score: 15.47, best_score: 15.64, epsilon: 0.1
#
# Game 399
# Episode: 398, score: 12.0, avg_score: 15.46, best_score: 15.64, epsilon: 0.1
#
# Game 400
# Episode: 399, score: 10.0, avg_score: 15.38, best_score: 15.64, epsilon: 0.1
#
# Game 401
# Episode: 400, score: 19.0, avg_score: 15.46, best_score: 15.64, epsilon: 0.1
#
# Game 402
# Episode: 401, score: 16.0, avg_score: 15.48, best_score: 15.64, epsilon: 0.1
#
# Game 403
# Episode: 402, score: 12.0, avg_score: 15.47, best_score: 15.64, epsilon: 0.1
#
# Game 404
# Episode: 403, score: 15.0, avg_score: 15.47, best_score: 15.64, epsilon: 0.1
#
# Game 405
# Episode: 404, score: 16.0, avg_score: 15.42, best_score: 15.64, epsilon: 0.1
#
# Game 406
# Episode: 405, score: 14.0, avg_score: 15.41, best_score: 15.64, epsilon: 0.1
#
# Game 407
# Episode: 406, score: 12.0, avg_score: 15.39, best_score: 15.64, epsilon: 0.1
#
# Game 408
# Episode: 407, score: 17.0, avg_score: 15.42, best_score: 15.64, epsilon: 0.1
#
# Game 409
# Episode: 408, score: 15.0, avg_score: 15.38, best_score: 15.64, epsilon: 0.1
#
# Game 410
# Episode: 409, score: 15.0, avg_score: 15.37, best_score: 15.64, epsilon: 0.1
#
# Game 411
# Episode: 410, score: 17.0, avg_score: 15.4, best_score: 15.64, epsilon: 0.1
#
# Game 412
# Episode: 411, score: 18.0, avg_score: 15.42, best_score: 15.64, epsilon: 0.1
#
# Game 413
# Episode: 412, score: 12.0, avg_score: 15.43, best_score: 15.64, epsilon: 0.1
#
# Game 414
# Episode: 413, score: 1.0, avg_score: 15.27, best_score: 15.64, epsilon: 0.1
#
# Game 415
# Episode: 414, score: 14.0, avg_score: 15.28, best_score: 15.64, epsilon: 0.1
#
# Game 416
# Episode: 415, score: 11.0, avg_score: 15.21, best_score: 15.64, epsilon: 0.1
#
# Game 417
# Episode: 416, score: 15.0, avg_score: 15.17, best_score: 15.64, epsilon: 0.1
#
# Game 418
# Episode: 417, score: 12.0, avg_score: 15.09, best_score: 15.64, epsilon: 0.1
#
# Game 419
# Episode: 418, score: 17.0, avg_score: 15.16, best_score: 15.64, epsilon: 0.1
#
# Game 420
# Episode: 419, score: 14.0, avg_score: 15.16, best_score: 15.64, epsilon: 0.1
#
# Game 421
# Episode: 420, score: 17.0, avg_score: 15.15, best_score: 15.64, epsilon: 0.1
#
# Game 422
# Episode: 421, score: 8.0, avg_score: 15.08, best_score: 15.64, epsilon: 0.1
#
# Game 423
# Episode: 422, score: 17.0, avg_score: 15.09, best_score: 15.64, epsilon: 0.1
#
# Game 424
# Episode: 423, score: 13.0, avg_score: 15.04, best_score: 15.64, epsilon: 0.1
#
# Game 425
# Episode: 424, score: 18.0, avg_score: 15.07, best_score: 15.64, epsilon: 0.1
#
# Game 426
# Episode: 425, score: 12.0, avg_score: 15.05, best_score: 15.64, epsilon: 0.1
#
# Game 427
# Episode: 426, score: 17.0, avg_score: 15.07, best_score: 15.64, epsilon: 0.1
#
# Game 428
# Episode: 427, score: 16.0, avg_score: 15.07, best_score: 15.64, epsilon: 0.1
#
# Game 429
# Episode: 428, score: 19.0, avg_score: 15.13, best_score: 15.64, epsilon: 0.1
#
# Game 430
# Episode: 429, score: 16.0, avg_score: 15.13, best_score: 15.64, epsilon: 0.1
#
# Game 431
# Episode: 430, score: 16.0, avg_score: 15.14, best_score: 15.64, epsilon: 0.1
#
# Game 432
# Episode: 431, score: 15.0, avg_score: 15.13, best_score: 15.64, epsilon: 0.1
#
# Game 433
# Episode: 432, score: 16.0, avg_score: 15.13, best_score: 15.64, epsilon: 0.1
#
# Game 434
# Episode: 433, score: 16.0, avg_score: 15.12, best_score: 15.64, epsilon: 0.1
#
# Game 435
# Episode: 434, score: 13.0, avg_score: 15.11, best_score: 15.64, epsilon: 0.1
#
# Game 436
# Episode: 435, score: 16.0, avg_score: 15.08, best_score: 15.64, epsilon: 0.1
#
# Game 437
# Episode: 436, score: 16.0, avg_score: 15.11, best_score: 15.64, epsilon: 0.1
#
# Game 438
# Episode: 437, score: 11.0, avg_score: 15.07, best_score: 15.64, epsilon: 0.1
#
# Game 439
# Episode: 438, score: 16.0, avg_score: 15.08, best_score: 15.64, epsilon: 0.1
#
# Game 440
# Episode: 439, score: 18.0, avg_score: 15.11, best_score: 15.64, epsilon: 0.1
#
# Game 441
# Episode: 440, score: 13.0, avg_score: 15.07, best_score: 15.64, epsilon: 0.1
#
# Game 442
# Episode: 441, score: 16.0, avg_score: 15.09, best_score: 15.64, epsilon: 0.1
#
# Game 443
# Episode: 442, score: 18.0, avg_score: 15.21, best_score: 15.64, epsilon: 0.1
#
# Game 444
# Episode: 443, score: 18.0, avg_score: 15.21, best_score: 15.64, epsilon: 0.1
#
# Game 445
# Episode: 444, score: 15.0, avg_score: 15.24, best_score: 15.64, epsilon: 0.1
#
# Game 446
# Episode: 445, score: 5.0, avg_score: 15.12, best_score: 15.64, epsilon: 0.1
#
# Game 447
# Episode: 446, score: 16.0, avg_score: 15.09, best_score: 15.64, epsilon: 0.1
#
# Game 448
# Episode: 447, score: 13.0, avg_score: 15.06, best_score: 15.64, epsilon: 0.1
#
# Game 449
# Episode: 448, score: 16.0, avg_score: 15.08, best_score: 15.64, epsilon: 0.1
#
# Game 450
# Episode: 449, score: 13.0, avg_score: 15.07, best_score: 15.64, epsilon: 0.1
#
# Game 451
# Episode: 450, score: 11.0, avg_score: 15.05, best_score: 15.64, epsilon: 0.1
#
# Game 452
# Episode: 451, score: 14.0, avg_score: 15.03, best_score: 15.64, epsilon: 0.1
#
# Game 453
# Episode: 452, score: 17.0, avg_score: 15.03, best_score: 15.64, epsilon: 0.1
#
# Game 454
# Episode: 453, score: 17.0, avg_score: 15.05, best_score: 15.64, epsilon: 0.1
#
# Game 455
# Episode: 454, score: 19.0, avg_score: 15.07, best_score: 15.64, epsilon: 0.1
#
# Game 456
# Episode: 455, score: 11.0, avg_score: 14.97, best_score: 15.64, epsilon: 0.1
#
# Game 457
# Episode: 456, score: 9.0, avg_score: 14.92, best_score: 15.64, epsilon: 0.1
#
# Game 458
# Episode: 457, score: 13.0, avg_score: 14.86, best_score: 15.64, epsilon: 0.1
#
# Game 459
# Episode: 458, score: 20.0, avg_score: 14.91, best_score: 15.64, epsilon: 0.1
#
# Game 460
# Episode: 459, score: 20.0, avg_score: 14.94, best_score: 15.64, epsilon: 0.1
#
# Game 461
# Episode: 460, score: 14.0, avg_score: 14.94, best_score: 15.64, epsilon: 0.1
#
# Game 462
# Episode: 461, score: 19.0, avg_score: 14.97, best_score: 15.64, epsilon: 0.1
#
# Game 463
# Episode: 462, score: 11.0, avg_score: 14.91, best_score: 15.64, epsilon: 0.1
#
# Game 464
# Episode: 463, score: 14.0, avg_score: 14.95, best_score: 15.64, epsilon: 0.1
#
# Game 465
# Episode: 464, score: 20.0, avg_score: 14.98, best_score: 15.64, epsilon: 0.1
#
# Game 466
# Episode: 465, score: 18.0, avg_score: 15.01, best_score: 15.64, epsilon: 0.1
#
# Game 467
# Episode: 466, score: 17.0, avg_score: 14.97, best_score: 15.64, epsilon: 0.1
#
# Game 468
# Episode: 467, score: 14.0, avg_score: 14.97, best_score: 15.64, epsilon: 0.1
#
# Game 469
# Episode: 468, score: 15.0, avg_score: 14.95, best_score: 15.64, epsilon: 0.1
#
# Game 470
# Episode: 469, score: 16.0, avg_score: 14.97, best_score: 15.64, epsilon: 0.1
#
# Game 471
# Episode: 470, score: 13.0, avg_score: 14.97, best_score: 15.64, epsilon: 0.1
#
# Game 472
# Episode: 471, score: 14.0, avg_score: 14.94, best_score: 15.64, epsilon: 0.1
#
# Game 473
# Episode: 472, score: 15.0, avg_score: 14.94, best_score: 15.64, epsilon: 0.1
#
# Game 474
# Episode: 473, score: 13.0, avg_score: 14.91, best_score: 15.64, epsilon: 0.1
#
# Game 475
# Episode: 474, score: 15.0, avg_score: 14.89, best_score: 15.64, epsilon: 0.1
#
# Game 476
# Episode: 475, score: 19.0, avg_score: 14.99, best_score: 15.64, epsilon: 0.1
#
# Game 477
# Episode: 476, score: 15.0, avg_score: 14.95, best_score: 15.64, epsilon: 0.1
#
# Game 478
# Episode: 477, score: 12.0, avg_score: 14.9, best_score: 15.64, epsilon: 0.1
#
# Game 479
# Episode: 478, score: 18.0, avg_score: 14.91, best_score: 15.64, epsilon: 0.1
#
# Game 480
# Episode: 479, score: 17.0, avg_score: 14.94, best_score: 15.64, epsilon: 0.1
#
# Game 481
# Episode: 480, score: 17.0, avg_score: 14.92, best_score: 15.64, epsilon: 0.1
#
# Game 482
# Episode: 481, score: 5.0, avg_score: 14.81, best_score: 15.64, epsilon: 0.1
#
# Game 483
# Episode: 482, score: 18.0, avg_score: 14.84, best_score: 15.64, epsilon: 0.1
#
# Game 484
# Episode: 483, score: 14.0, avg_score: 14.81, best_score: 15.64, epsilon: 0.1
#
# Game 485
# Episode: 484, score: 15.0, avg_score: 14.8, best_score: 15.64, epsilon: 0.1
#
# Game 486
# Episode: 485, score: 18.0, avg_score: 14.79, best_score: 15.64, epsilon: 0.1
#
# Game 487
# Episode: 486, score: 17.0, avg_score: 14.83, best_score: 15.64, epsilon: 0.1
#
# Game 488
# Episode: 487, score: 15.0, avg_score: 14.81, best_score: 15.64, epsilon: 0.1
#
# Game 489
# Episode: 488, score: 20.0, avg_score: 14.84, best_score: 15.64, epsilon: 0.1
#
# Game 490
# Episode: 489, score: 16.0, avg_score: 14.91, best_score: 15.64, epsilon: 0.1
#
# Game 491
# Episode: 490, score: 15.0, avg_score: 14.91, best_score: 15.64, epsilon: 0.1
#
# Game 492
# Episode: 491, score: 8.0, avg_score: 14.84, best_score: 15.64, epsilon: 0.1
#
# Game 493
# Episode: 492, score: 14.0, avg_score: 14.82, best_score: 15.64, epsilon: 0.1
#
# Game 494
# Episode: 493, score: 18.0, avg_score: 14.9, best_score: 15.64, epsilon: 0.1
#
# Game 495
# Episode: 494, score: 19.0, avg_score: 14.9, best_score: 15.64, epsilon: 0.1
#
# Game 496
# Episode: 495, score: 12.0, avg_score: 14.83, best_score: 15.64, epsilon: 0.1
#
# Game 497
# Episode: 496, score: 18.0, avg_score: 14.82, best_score: 15.64, epsilon: 0.1
#
# Game 498
# Episode: 497, score: 14.0, avg_score: 14.86, best_score: 15.64, epsilon: 0.1
#
# Game 499
# Episode: 498, score: 15.0, avg_score: 14.89, best_score: 15.64, epsilon: 0.1
#
# Game 500
# Episode: 499, score: 10.0, avg_score: 14.89, best_score: 15.64, epsilon: 0.1
