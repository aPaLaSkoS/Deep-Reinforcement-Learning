# %%
# !pip install "gym[atari, accept-rom-license]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym[accept-rom-license,atari] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (0.0.8)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (0.4.2)
# Requirement already satisfied: ale-py~=0.7.5 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (0.7.5)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.7.5->gym[accept-rom-license,atari]) (5.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.27.1)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (0.6.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.0.12)

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
import collections
import cv2
import os
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Classes + Helpers

# %% [markdown]
# ## Environment

# %%
class RepeatActionAndMaxFrame(gym.Wrapper):
  def __init__(self, env=None, repeat=4, clip_rewards=False, no_ops=0, fire_first=False):
    super(RepeatActionAndMaxFrame, self).__init__(env)
    self.repeat = repeat
    self.shape = env.observation_space.low.shape
    self.frame_buffer = np.zeros_like((2, self.shape))
    self.clip_rewards = clip_rewards
    self.no_ops = no_ops
    self.fire_first = fire_first

  def step(self, action):
    total_reward = 0.0
    done = False
    for i in range(self.repeat):
      obs, reward, done, info = self.env.step(action)
      if self.clip_rewards:
        reward = np.clip(np.array([reward]), -1, 1)[0]
      total_reward += reward
      idx = i % 2
      self.frame_buffer[idx] = obs
      if done:
        break

    max_frame = np.maximum(self.frame_buffer[0], self.frame_buffer[1])
    return max_frame, total_reward, done, info

  def reset(self):
    obs = self.env.reset()
    no_ops = np.random.randint(self.no_ops) + 1 if self.no_ops > 0 else 0
    for _ in range(no_ops):
      _, _, done, _ = self.env.step(0)
      if done:
        self.env.reset()
    if self.fire_first:
      assert self.env.unwrapped.get_action_meanings()[1] == 'FIRE'
      obs, _, _, _ = self.env.step(1)

    self.frame_buffer = np.zeros_like((2, self.shape))
    self.frame_buffer[0] = obs
    return obs


class PreprocessFrame(gym.ObservationWrapper):
  def __init__(self, shape, env=None):
    super(PreprocessFrame, self).__init__(env)
    self.shape = (shape[2], shape[0], shape[1])
    self.observation_space = gym.spaces.Box(low=0.0, high=1.0,
                                            shape=self.shape,
                                            dtype=np.float32)

  def observation(self, obs):
    new_frame = cv2.cvtColor(obs, cv2.COLOR_BGR2GRAY)
    resized_screen = cv2.resize(new_frame,
                                self.shape[1:],
                                interpolation=cv2.INTER_AREA)
    new_obs = np.array(resized_screen, dtype=np.float16).reshape(self.shape)
    new_obs /= 255.0

    return new_obs


class StackFrames(gym.ObservationWrapper):
  def __init__(self, env, repeat):
    super(StackFrames, self).__init__(env)
    self.observation_space = gym.spaces.Box(
        env.observation_space.low.repeat(repeat, axis=0),
        env.observation_space.high.repeat(repeat, axis=0)
    )
    self.stack = collections.deque(maxlen=repeat)

  def reset(self):
    self.stack.clear()
    observation = self.env.reset()
    for _ in range(self.stack.maxlen):
      self.stack.append(observation)

    return np.array(self.stack).reshape(self.observation_space.low.shape)

  def observation(self, observation):
    self.stack.append(observation)
    return np.array(self.stack).reshape(self.observation_space.low.shape)


def make_env(env_name, shape=(84, 84, 1), repeat=4, clip_rewards=False, no_ops=0, fire_first=False):
  env = gym.make(env_name)
  env = RepeatActionAndMaxFrame(env, repeat, clip_rewards, no_ops, fire_first)
  env = PreprocessFrame(shape, env)
  env = StackFrames(env, repeat)
  return env

# %% [markdown]
# ## Agent

# %%
class ReplayBuffer():
  def __init__(self, max_size, input_shape, n_actions):
    self.mem_size = max_size
    self.mem_counter = 0
    self.state_memory = np.zeros(
        (self.mem_size, *input_shape),
        dtype=np.float32
    )
    self.new_state_memory = np.zeros(
        (self.mem_size, *input_shape),
        dtype=np.float32
    )
    self.action_memory = np.zeros(self.mem_size, dtype=np.int64)
    self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
    self.terminal_memory = np.zeros(self.mem_size, dtype=np.uint8)

  def store_transition(self, state, action, reward, state_, done):
    index = self.mem_counter % self.mem_size
    self.state_memory[index] = state
    self.action_memory[index] = action
    self.reward_memory[index] = reward
    self.new_state_memory[index] = state_
    self.terminal_memory[index] = done
    self.mem_counter += 1

  def sample_buffer(self, batch_size):
    max_mem = min(self.mem_counter, self.mem_size)
    batch = np.random.choice(max_mem, batch_size, replace=True)
    states = self.state_memory[batch]
    actions = self.action_memory[batch]
    rewards = self.reward_memory[batch]
    states_ = self.new_state_memory[batch]
    dones = self.terminal_memory[batch]

    return states, actions, rewards, states_, dones


class DeepQNetwork(nn.Module):
  def __init__(self, lr, n_actions, name, input_dims, chkpt_dir):
    super(DeepQNetwork, self).__init__()
    self.checkpoint_dir = chkpt_dir
    self.checkpoint_file = os.path.join(self.checkpoint_dir, name)
    if not os.path.exists(self.checkpoint_dir):
      os.makedirs(self.checkpoint_dir)

    self.conv1 = nn.Conv2d(input_dims[0], 32, 8, stride=4)
    self.conv2 = nn.Conv2d(32, 64, 4, stride=2)
    self.conv3 = nn.Conv2d(64, 64, 3, stride=1)

    fc_input_dims = self.calculate_conv_output_dims(input_dims)

    self.fc1 = nn.Linear(fc_input_dims, 512)
    self.fc2 = nn.Linear(512, n_actions)

    self.optimizer = optim.RMSprop(self.parameters(), lr=lr)
    self.loss = nn.MSELoss()
    self.device = T.device('cuda' if T.cuda.is_available() else 'cpu')
    self.to(self.device)

  def calculate_conv_output_dims(self, input_dims):
    state = T.zeros(1, *input_dims)
    dims = self.conv1(state)
    dims = self.conv2(dims)
    dims = self.conv3(dims)
    return int(np.prod(dims.size()))

  def forward(self, state):
    state = F.relu(self.conv1(state))
    state = F.relu(self.conv2(state))
    state = F.relu(self.conv3(state))
    # conv3 shape is: batch_size x n_filters x H x W
    state = state.view(state.size()[0], -1)
    state = F.relu(self.fc1(state))
    actions = self.fc2(state)

    return actions

  def save_checkpoint(self):
    print('... saving checkpoint ...')
    T.save(self.state_dict(), self.checkpoint_file)

  def load_checkpoint(self):
    print('... loading checkpoint ...')
    self.load_state_dict(T.load(self.checkpoint_file))


class DQNAgent():
  def __init__(self, gamma, epsilon, lr, n_actions, input_dims,
               mem_size, batch_size, eps_min=0.01, eps_dec=5e-7,
               replace=1000, algo=None, env_name=None, chkpt_dir='tmp/dqn'):
    self.gamma = gamma
    self.epsilon = epsilon
    self.lr = lr
    self.n_actions = n_actions
    self.input_dims = input_dims
    self.batch_size = batch_size
    self.eps_min = eps_min
    self.eps_dec = eps_dec
    self.replace_target_counter = replace
    self.algo = algo
    self.env_name = env_name
    self.chkpt_dir = chkpt_dir
    self.action_space = [i for i in range(self.n_actions)]
    self.learn_step_counter = 0

    self.memory = ReplayBuffer(mem_size, input_dims, n_actions)

    self.Q_eval = DeepQNetwork(self.lr, self.n_actions,
                               input_dims=self.input_dims,
                               name=self.env_name + '_' + self.algo + '_Q_eval.pth',
                               chkpt_dir=self.chkpt_dir)

    self.Q_next = DeepQNetwork(self.lr, self.n_actions,
                               input_dims=self.input_dims,
                               name=self.env_name + '_' + self.algo + '_Q_next.pth',
                               chkpt_dir=self.chkpt_dir)

  def choose_action(self, observation):
    if np.random.random() > self.epsilon:
      state = T.tensor([observation], dtype=T.float).to(self.Q_eval.device)
      actions = self.Q_eval.forward(state)
      action = T.argmax(actions).item()
    else:
      action = np.random.choice(self.action_space)
    return action

  def store_transition(self, state, action, reward, state_, done):
    self.memory.store_transition(state, action, reward, state_, done)

  def sample_memory(self):
    state, action, reward, new_state, done = self.memory.sample_buffer(self.batch_size)
    states = T.tensor(state).to(self.Q_eval.device)
    actions = T.tensor(action).to(self.Q_eval.device)
    rewards = T.tensor(reward).to(self.Q_eval.device)
    states_ = T.tensor(new_state).to(self.Q_eval.device)
    dones = T.tensor(done).to(self.Q_eval.device)

    return states, actions, rewards, states_, dones

  def replace_target_network(self):
    if self.learn_step_counter % self.replace_target_counter == 0:
      self.Q_next.load_state_dict(self.Q_eval.state_dict())

  def decrement_epsilon(self):
    self.epsilon = self.epsilon - self.eps_dec if self.epsilon > self.eps_min else self.eps_min

  def save_models(self):
    self.Q_eval.save_checkpoint()
    self.Q_next.save_checkpoint()

  def load_models(self):
    self.Q_eval.load_checkpoint()
    self.Q_next.load_checkpoint()

  def learn(self):
    if self.memory.mem_counter < self.batch_size:
      return

    self.Q_eval.optimizer.zero_grad()

    self.replace_target_network()
    states, actions, rewards, states_, dones = self.sample_memory()

    indices = np.arange(self.batch_size)
    Q_pred = self.Q_eval.forward(states)[indices, actions]
    Q_next = self.Q_next.forward(states_).max(dim=1)[00]

    # where the episodes reach a terminal state (done=1),
    # there the target must be equal to r
    Q_next[dones] = 0.0
    Q_target = rewards + self.gamma * Q_next

    loss = self.Q_eval.loss(Q_target, Q_pred).to(self.Q_eval.device)
    loss.backward()
    self.Q_eval.optimizer.step()
    self.learn_step_counter += 1

    self.decrement_epsilon()

# %% [markdown]
# ## Other

# %%
def  plot_learning_curve(x, scores, epsilons, lines=None):
  fig = plt.figure(figsize=(30, 10))
  ax = fig.add_subplot(111, label='1')
  ax2 = fig.add_subplot(111, label='2', frame_on=False)

  ax.plot(x, epsilons, color='C0', label='Epsilon')
  ax.set_xlabel("Training steps", color="C0")
  ax.set_ylabel("Epsilon", color="C0")
  ax.tick_params(axis='x', colors="C0")
  ax.tick_params(axis='y', colors='C0')
  ax.legend(loc='upper left', labelcolor="C0")

  N = len(scores)
  running_avg = np.empty(N)
  for t in range(N):
    running_avg[t] = np.mean(scores[max(0, t-20):(t+1)])

  ax2.scatter(x, running_avg, color="C1", label="Score")
  ax2.axes.get_xaxis().set_visible(False)
  ax2.yaxis.tick_right()
  ax2.set_ylabel('Score', color="C1")
  ax2.yaxis.set_label_position('right')
  ax2.tick_params(axis='y', colors="C1")
  ax2.legend(loc='upper right', labelcolor="C1")

  if lines is not None:
    for line in lines:
      plt.axvline(x=line)

  plt.title("Deep Q-Learning for Atari")
  plt.show()

  # plt.savefig(filename)

# %% [markdown]
# # MAIN

# %%
# !rm -rf './models'
env = make_env('PongNoFrameskip-v4')

best_score = -np.inf
load_checkpoint = False
n_games = 500

agent = DQNAgent(gamma=0.99, epsilon=1.0, lr=1e-4,
                input_dims=(env.observation_space.shape),
                n_actions=env.action_space.n, mem_size=20000,
                eps_min=0.1, batch_size=32, replace=1000,
                eps_dec=1e-5, chkpt_dir='models/',
                algo='DQNAgent', env_name='PongNoFrameskip-v4')

if load_checkpoint:
  agent.load_models()

# file_name = agent.algo +'_' + agent.env_name + '_lr' + str(agent.lr) + '_' + str(n_games) + '_games'
# figure_file = 'plots/' + file_name + '.png'

n_steps = 0
scores, eps_history, steps_array = [], [], []

for i in range(n_games):
  print(f"\nGame {i+1}")
  done = False
  score = 0
  observation = env.reset()

  while not done:
    action = agent.choose_action(observation)
    observation_, reward, done, info = env.step(action)
    score += reward

    if not load_checkpoint:
      agent.store_transition(observation, action, reward, observation_, int(done))
      agent.learn()

    observation = observation_
    n_steps += 1

  scores.append(score)
  steps_array.append(n_steps)

  avg_score = np.mean(scores[-100:])
  print(f"Episode: {i}, score: {score}, avg_score: {avg_score}, best_score: {best_score}, epsilon: {agent.epsilon}")

  if avg_score > best_score:
    if not load_checkpoint:
      agent.save_models()
    best_score = avg_score

  eps_history.append(agent.epsilon)

plot_learning_curve(steps_array, scores, eps_history)
# Out:
# Game 1
# Episode: 0, score: -19.0, avg_score: -19.0, best_score: -inf, epsilon: 0.9897500000000466
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 2
# Episode: 1, score: -20.0, avg_score: -19.5, best_score: -19.0, epsilon: 0.9805800000000884
#
# Game 3
# Episode: 2, score: -19.0, avg_score: -19.333333333333332, best_score: -19.0, epsilon: 0.9706100000001338
#
# Game 4
# Episode: 3, score: -21.0, avg_score: -19.75, best_score: -19.0, epsilon: 0.9615800000001749
#
# Game 5
# Episode: 4, score: -20.0, avg_score: -19.8, best_score: -19.0, epsilon: 0.9530200000002138
#
# Game 6
# Episode: 5, score: -21.0, avg_score: -20.0, best_score: -19.0, epsilon: 0.9447500000002514
#
# Game 7
# Episode: 6, score: -21.0, avg_score: -20.142857142857142, best_score: -19.0, epsilon: 0.9366400000002884
#
# Game 8
# Episode: 7, score: -20.0, avg_score: -20.125, best_score: -19.0, epsilon: 0.9261200000003362
#
# Game 9
# Episode: 8, score: -21.0, avg_score: -20.22222222222222, best_score: -19.0, epsilon: 0.9164900000003801
#
# Game 10
# Episode: 9, score: -21.0, avg_score: -20.3, best_score: -19.0, epsilon: 0.9082800000004174
#
# Game 11
# Episode: 10, score: -21.0, avg_score: -20.363636363636363, best_score: -19.0, epsilon: 0.8997500000004562
#
# Game 12
# Episode: 11, score: -21.0, avg_score: -20.416666666666668, best_score: -19.0, epsilon: 0.8892000000005043
epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 255
# Episode: 254, score: 16.0, avg_score: 14.73, best_score: 14.74, epsilon: 0.1
#
# Game 256
# Episode: 255, score: 9.0, avg_score: 14.73, best_score: 14.74, epsilon: 0.1
#
# Game 257
# Episode: 256, score: 16.0, avg_score: 14.71, best_score: 14.74, epsilon: 0.1
#
# Game 258
# Episode: 257, score: 16.0, avg_score: 14.7, best_score: 14.74, epsilon: 0.1
#
# Game 259
# Episode: 258, score: 13.0, avg_score: 14.71, best_score: 14.74, epsilon: 0.1
#
# Game 260
# Episode: 259, score: 11.0, avg_score: 14.67, best_score: 14.74, epsilon: 0.1
#
# Game 261
# Episode: 260, score: 9.0, avg_score: 14.61, best_score: 14.74, epsilon: 0.1
#
# Game 262
# Episode: 261, score: 16.0, avg_score: 14.61, best_score: 14.74, epsilon: 0.1
#
# Game 263
# Episode: 262, score: 17.0, avg_score: 14.64, best_score: 14.74, epsilon: 0.1
#
# Game 264
# Episode: 263, score: 11.0, avg_score: 14.66, best_score: 14.74, epsilon: 0.1
#
# Game 265
# Episode: 264, score: 15.0, avg_score: 14.64, best_score: 14.74, epsilon: 0.1
#
# Game 266
# Episode: 265, score: 15.0, avg_score: 14.62, best_score: 14.74, epsilon: 0.1
#
# Game 267
# Episode: 266, score: 14.0, avg_score: 14.7, best_score: 14.74, epsilon: 0.1
#
# Game 268
# Episode: 267, score: 16.0, avg_score: 14.71, best_score: 14.74, epsilon: 0.1
#
# Game 269
# Episode: 268, score: 15.0, avg_score: 14.72, best_score: 14.74, epsilon: 0.1
#
# Game 270
# Episode: 269, score: 15.0, avg_score: 14.78, best_score: 14.74, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 271
# Episode: 270, score: 8.0, avg_score: 14.76, best_score: 14.78, epsilon: 0.1
#
# Game 272
# Episode: 271, score: 17.0, avg_score: 14.78, best_score: 14.78, epsilon: 0.1
#
# Game 273
# Episode: 272, score: 17.0, avg_score: 14.8, best_score: 14.78, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 274
# Episode: 273, score: 11.0, avg_score: 14.73, best_score: 14.8, epsilon: 0.1
#
# Game 275
# Episode: 274, score: 19.0, avg_score: 14.82, best_score: 14.8, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 276
# Episode: 275, score: 20.0, avg_score: 14.89, best_score: 14.82, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 277
# Episode: 276, score: 6.0, avg_score: 14.78, best_score: 14.89, epsilon: 0.1
#
# Game 278
# Episode: 277, score: 8.0, avg_score: 14.72, best_score: 14.89, epsilon: 0.1
#
# Game 279
# Episode: 278, score: 14.0, avg_score: 14.69, best_score: 14.89, epsilon: 0.1
#
# Game 280
# Episode: 279, score: 15.0, avg_score: 14.74, best_score: 14.89, epsilon: 0.1
#
# Game 281
# Episode: 280, score: 16.0, avg_score: 14.8, best_score: 14.89, epsilon: 0.1
#
# Game 282
# Episode: 281, score: 16.0, avg_score: 14.86, best_score: 14.89, epsilon: 0.1
#
# Game 283
# Episode: 282, score: 19.0, avg_score: 14.96, best_score: 14.89, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 284
# Episode: 283, score: 19.0, avg_score: 15.02, best_score: 14.96, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 285
# Episode: 284, score: 12.0, avg_score: 14.97, best_score: 15.02, epsilon: 0.1
#
# Game 286
# Episode: 285, score: 15.0, avg_score: 15.0, best_score: 15.02, epsilon: 0.1
#
# Game 287
# Episode: 286, score: 13.0, avg_score: 14.95, best_score: 15.02, epsilon: 0.1
#
# Game 288
# Episode: 287, score: 18.0, avg_score: 14.99, best_score: 15.02, epsilon: 0.1
#
# Game 289
# Episode: 288, score: 17.0, avg_score: 14.98, best_score: 15.02, epsilon: 0.1
#
# Game 290
# Episode: 289, score: 15.0, avg_score: 14.99, best_score: 15.02, epsilon: 0.1
#
# Game 291
# Episode: 290, score: 19.0, avg_score: 15.03, best_score: 15.02, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 292
# Episode: 291, score: 19.0, avg_score: 15.04, best_score: 15.03, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 293
# Episode: 292, score: 15.0, avg_score: 15.07, best_score: 15.04, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 294
# Episode: 293, score: 12.0, avg_score: 15.02, best_score: 15.07, epsilon: 0.1
#
# Game 295
# Episode: 294, score: 16.0, avg_score: 15.0, best_score: 15.07, epsilon: 0.1
#
# Game 296
# Episode: 295, score: 14.0, avg_score: 14.99, best_score: 15.07, epsilon: 0.1
#
# Game 297
# Episode: 296, score: 15.0, avg_score: 14.99, best_score: 15.07, epsilon: 0.1
#
# Game 298
# Episode: 297, score: 13.0, avg_score: 14.96, best_score: 15.07, epsilon: 0.1
#
# Game 299
# Episode: 298, score: 12.0, avg_score: 14.93, best_score: 15.07, epsilon: 0.1
#
# Game 300
# Episode: 299, score: 10.0, avg_score: 14.94, best_score: 15.07, epsilon: 0.1
#
# Game 301
# Episode: 300, score: 16.0, avg_score: 14.98, best_score: 15.07, epsilon: 0.1
#
# Game 302
# Episode: 301, score: 18.0, avg_score: 15.04, best_score: 15.07, epsilon: 0.1
#
# Game 303
# Episode: 302, score: 15.0, avg_score: 15.05, best_score: 15.07, epsilon: 0.1
#
# Game 304
# Episode: 303, score: 14.0, avg_score: 15.04, best_score: 15.07, epsilon: 0.1
#
# Game 305
# Episode: 304, score: 18.0, avg_score: 15.09, best_score: 15.07, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 306
# Episode: 305, score: 17.0, avg_score: 15.13, best_score: 15.09, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 307
# Episode: 306, score: 17.0, avg_score: 15.18, best_score: 15.13, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 308
# Episode: 307, score: 15.0, avg_score: 15.16, best_score: 15.18, epsilon: 0.1
#
# Game 309
# Episode: 308, score: 12.0, avg_score: 15.11, best_score: 15.18, epsilon: 0.1
#
# Game 310
# Episode: 309, score: 9.0, avg_score: 15.04, best_score: 15.18, epsilon: 0.1
#
# Game 311
# Episode: 310, score: 18.0, avg_score: 15.1, best_score: 15.18, epsilon: 0.1
#
# Game 312
# Episode: 311, score: 16.0, avg_score: 15.07, best_score: 15.18, epsilon: 0.1
#
# Game 313
# Episode: 312, score: 12.0, avg_score: 15.01, best_score: 15.18, epsilon: 0.1
#
# Game 314
# Episode: 313, score: 14.0, avg_score: 15.0, best_score: 15.18, epsilon: 0.1
#
# Game 315
# Episode: 314, score: 16.0, avg_score: 15.01, best_score: 15.18, epsilon: 0.1
#
# Game 316
# Episode: 315, score: 19.0, avg_score: 15.05, best_score: 15.18, epsilon: 0.1
#
# Game 317
# Episode: 316, score: 18.0, avg_score: 15.21, best_score: 15.18, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 318
# Episode: 317, score: 15.0, avg_score: 15.16, best_score: 15.21, epsilon: 0.1
#
# Game 319
# Episode: 318, score: 13.0, avg_score: 15.13, best_score: 15.21, epsilon: 0.1
#
# Game 320
# Episode: 319, score: 14.0, avg_score: 15.09, best_score: 15.21, epsilon: 0.1
#
# Game 321
# Episode: 320, score: 19.0, avg_score: 15.12, best_score: 15.21, epsilon: 0.1
#
# Game 322
# Episode: 321, score: 13.0, avg_score: 15.15, best_score: 15.21, epsilon: 0.1
#
# Game 323
# Episode: 322, score: 16.0, avg_score: 15.16, best_score: 15.21, epsilon: 0.1
#
# Game 324
# Episode: 323, score: 18.0, avg_score: 15.17, best_score: 15.21, epsilon: 0.1
#
# Game 325
# Episode: 324, score: 15.0, avg_score: 15.18, best_score: 15.21, epsilon: 0.1
#
# Game 326
# Episode: 325, score: 15.0, avg_score: 15.16, best_score: 15.21, epsilon: 0.1
#
# Game 327
# Episode: 326, score: 18.0, avg_score: 15.18, best_score: 15.21, epsilon: 0.1
#
# Game 328
# Episode: 327, score: 9.0, avg_score: 15.11, best_score: 15.21, epsilon: 0.1
#
# Game 329
# Episode: 328, score: 12.0, avg_score: 15.12, best_score: 15.21, epsilon: 0.1
#
# Game 330
# Episode: 329, score: 13.0, avg_score: 15.09, best_score: 15.21, epsilon: 0.1
#
# Game 331
# Episode: 330, score: 18.0, avg_score: 15.1, best_score: 15.21, epsilon: 0.1
#
# Game 332
# Episode: 331, score: 19.0, avg_score: 15.13, best_score: 15.21, epsilon: 0.1
#
# Game 333
# Episode: 332, score: 19.0, avg_score: 15.17, best_score: 15.21, epsilon: 0.1
#
# Game 334
# Episode: 333, score: 11.0, avg_score: 15.13, best_score: 15.21, epsilon: 0.1
#
# Game 335
# Episode: 334, score: 9.0, avg_score: 15.02, best_score: 15.21, epsilon: 0.1
#
# Game 336
# Episode: 335, score: 13.0, avg_score: 14.98, best_score: 15.21, epsilon: 0.1
#
# Game 337
# Episode: 336, score: 15.0, avg_score: 14.98, best_score: 15.21, epsilon: 0.1
#
# Game 338
# Episode: 337, score: 20.0, avg_score: 15.01, best_score: 15.21, epsilon: 0.1
#
# Game 339
# Episode: 338, score: 11.0, avg_score: 14.99, best_score: 15.21, epsilon: 0.1
#
# Game 340
# Episode: 339, score: 17.0, avg_score: 14.98, best_score: 15.21, epsilon: 0.1
#
# Game 341
# Episode: 340, score: 15.0, avg_score: 14.97, best_score: 15.21, epsilon: 0.1
#
# Game 342
# Episode: 341, score: 16.0, avg_score: 14.98, best_score: 15.21, epsilon: 0.1
#
# Game 343
# Episode: 342, score: 12.0, avg_score: 14.95, best_score: 15.21, epsilon: 0.1
#
# Game 344
# Episode: 343, score: 19.0, avg_score: 14.96, best_score: 15.21, epsilon: 0.1
#
# Game 345
# Episode: 344, score: 13.0, avg_score: 14.91, best_score: 15.21, epsilon: 0.1
#
# Game 346
# Episode: 345, score: 17.0, avg_score: 14.94, best_score: 15.21, epsilon: 0.1
#
# Game 347
# Episode: 346, score: 19.0, avg_score: 14.92, best_score: 15.21, epsilon: 0.1
#
# Game 348
# Episode: 347, score: 18.0, avg_score: 14.98, best_score: 15.21, epsilon: 0.1
#
# Game 349
# Episode: 348, score: 19.0, avg_score: 15.01, best_score: 15.21, epsilon: 0.1
#
# Game 350
# Episode: 349, score: 17.0, avg_score: 15.04, best_score: 15.21, epsilon: 0.1
#
# Game 351
# Episode: 350, score: 9.0, avg_score: 14.94, best_score: 15.21, epsilon: 0.1
#
# Game 352
# Episode: 351, score: 13.0, avg_score: 14.91, best_score: 15.21, epsilon: 0.1
#
# Game 353
# Episode: 352, score: 15.0, avg_score: 14.88, best_score: 15.21, epsilon: 0.1
#
# Game 354
# Episode: 353, score: 18.0, avg_score: 14.9, best_score: 15.21, epsilon: 0.1
#
# Game 355
# Episode: 354, score: 21.0, avg_score: 14.95, best_score: 15.21, epsilon: 0.1
#
# Game 356
# Episode: 355, score: 13.0, avg_score: 14.99, best_score: 15.21, epsilon: 0.1
#
# Game 357
# Episode: 356, score: 17.0, avg_score: 15.0, best_score: 15.21, epsilon: 0.1
#
# Game 358
# Episode: 357, score: 16.0, avg_score: 15.0, best_score: 15.21, epsilon: 0.1
#
# Game 359
# Episode: 358, score: 18.0, avg_score: 15.05, best_score: 15.21, epsilon: 0.1
#
# Game 360
# Episode: 359, score: 13.0, avg_score: 15.07, best_score: 15.21, epsilon: 0.1
#
# Game 361
# Episode: 360, score: 16.0, avg_score: 15.14, best_score: 15.21, epsilon: 0.1
#
# Game 362
# Episode: 361, score: 9.0, avg_score: 15.07, best_score: 15.21, epsilon: 0.1
#
# Game 363
# Episode: 362, score: 19.0, avg_score: 15.09, best_score: 15.21, epsilon: 0.1
#
# Game 364
# Episode: 363, score: 19.0, avg_score: 15.17, best_score: 15.21, epsilon: 0.1
#
# Game 365
# Episode: 364, score: 17.0, avg_score: 15.19, best_score: 15.21, epsilon: 0.1
#
# Game 366
# Episode: 365, score: 18.0, avg_score: 15.22, best_score: 15.21, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 367
# Episode: 366, score: 13.0, avg_score: 15.21, best_score: 15.22, epsilon: 0.1
#
# Game 368
# Episode: 367, score: 17.0, avg_score: 15.22, best_score: 15.22, epsilon: 0.1
#
# Game 369
# Episode: 368, score: 11.0, avg_score: 15.18, best_score: 15.22, epsilon: 0.1
#
# Game 370
# Episode: 369, score: 17.0, avg_score: 15.2, best_score: 15.22, epsilon: 0.1
#
# Game 371
# Episode: 370, score: 20.0, avg_score: 15.32, best_score: 15.22, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 372
# Episode: 371, score: 13.0, avg_score: 15.28, best_score: 15.32, epsilon: 0.1
#
# Game 373
# Episode: 372, score: 17.0, avg_score: 15.28, best_score: 15.32, epsilon: 0.1
#
# Game 374
# Episode: 373, score: 6.0, avg_score: 15.23, best_score: 15.32, epsilon: 0.1
#
# Game 375
# Episode: 374, score: 19.0, avg_score: 15.23, best_score: 15.32, epsilon: 0.1
#
# Game 376
# Episode: 375, score: 16.0, avg_score: 15.19, best_score: 15.32, epsilon: 0.1
#
# Game 377
# Episode: 376, score: 16.0, avg_score: 15.29, best_score: 15.32, epsilon: 0.1
#
# Game 378
# Episode: 377, score: 13.0, avg_score: 15.34, best_score: 15.32, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 379
# Episode: 378, score: 16.0, avg_score: 15.36, best_score: 15.34, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 380
# Episode: 379, score: 16.0, avg_score: 15.37, best_score: 15.36, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 381
# Episode: 380, score: 12.0, avg_score: 15.33, best_score: 15.37, epsilon: 0.1
#
# Game 382
# Episode: 381, score: 15.0, avg_score: 15.32, best_score: 15.37, epsilon: 0.1
#
# Game 383
# Episode: 382, score: 18.0, avg_score: 15.31, best_score: 15.37, epsilon: 0.1
#
# Game 384
# Episode: 383, score: 17.0, avg_score: 15.29, best_score: 15.37, epsilon: 0.1
#
# Game 385
# Episode: 384, score: 17.0, avg_score: 15.34, best_score: 15.37, epsilon: 0.1
#
# Game 386
# Episode: 385, score: 16.0, avg_score: 15.35, best_score: 15.37, epsilon: 0.1
#
# Game 387
# Episode: 386, score: 16.0, avg_score: 15.38, best_score: 15.37, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 388
# Episode: 387, score: 12.0, avg_score: 15.32, best_score: 15.38, epsilon: 0.1
#
# Game 389
# Episode: 388, score: 18.0, avg_score: 15.33, best_score: 15.38, epsilon: 0.1
#
# Game 390
# Episode: 389, score: 19.0, avg_score: 15.37, best_score: 15.38, epsilon: 0.1
#
# Game 391
# Episode: 390, score: 18.0, avg_score: 15.36, best_score: 15.38, epsilon: 0.1
#
# Game 392
# Episode: 391, score: 18.0, avg_score: 15.35, best_score: 15.38, epsilon: 0.1
#
# Game 393
# Episode: 392, score: 17.0, avg_score: 15.37, best_score: 15.38, epsilon: 0.1
#
# Game 394
# Episode: 393, score: 12.0, avg_score: 15.37, best_score: 15.38, epsilon: 0.1
#
# Game 395
# Episode: 394, score: 19.0, avg_score: 15.4, best_score: 15.38, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 396
# Episode: 395, score: 15.0, avg_score: 15.41, best_score: 15.4, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 397
# Episode: 396, score: 18.0, avg_score: 15.44, best_score: 15.41, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 398
# Episode: 397, score: 17.0, avg_score: 15.48, best_score: 15.44, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 399
# Episode: 398, score: 11.0, avg_score: 15.47, best_score: 15.48, epsilon: 0.1
#
# Game 400
# Episode: 399, score: 11.0, avg_score: 15.48, best_score: 15.48, epsilon: 0.1
#
# Game 401
# Episode: 400, score: 16.0, avg_score: 15.48, best_score: 15.48, epsilon: 0.1
#
# Game 402
# Episode: 401, score: 18.0, avg_score: 15.48, best_score: 15.48, epsilon: 0.1
#
# Game 403
# Episode: 402, score: 15.0, avg_score: 15.48, best_score: 15.48, epsilon: 0.1
#
# Game 404
# Episode: 403, score: 19.0, avg_score: 15.53, best_score: 15.48, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 405
# Episode: 404, score: 16.0, avg_score: 15.51, best_score: 15.53, epsilon: 0.1
#
# Game 406
# Episode: 405, score: 18.0, avg_score: 15.52, best_score: 15.53, epsilon: 0.1
#
# Game 407
# Episode: 406, score: 16.0, avg_score: 15.51, best_score: 15.53, epsilon: 0.1
#
# Game 408
# Episode: 407, score: 15.0, avg_score: 15.51, best_score: 15.53, epsilon: 0.1
#
# Game 409
# Episode: 408, score: 19.0, avg_score: 15.58, best_score: 15.53, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 410
# Episode: 409, score: 20.0, avg_score: 15.69, best_score: 15.58, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 411
# Episode: 410, score: 12.0, avg_score: 15.63, best_score: 15.69, epsilon: 0.1
#
# Game 412
# Episode: 411, score: 13.0, avg_score: 15.6, best_score: 15.69, epsilon: 0.1
#
# Game 413
# Episode: 412, score: 7.0, avg_score: 15.55, best_score: 15.69, epsilon: 0.1
#
# Game 414
# Episode: 413, score: 13.0, avg_score: 15.54, best_score: 15.69, epsilon: 0.1
#
# Game 415
# Episode: 414, score: 8.0, avg_score: 15.46, best_score: 15.69, epsilon: 0.1
#
# Game 416
# Episode: 415, score: 19.0, avg_score: 15.46, best_score: 15.69, epsilon: 0.1
#
# Game 417
# Episode: 416, score: 13.0, avg_score: 15.41, best_score: 15.69, epsilon: 0.1
#
# Game 418
# Episode: 417, score: 21.0, avg_score: 15.47, best_score: 15.69, epsilon: 0.1
#
# Game 419
# Episode: 418, score: 12.0, avg_score: 15.46, best_score: 15.69, epsilon: 0.1
#
# Game 420
# Episode: 419, score: 18.0, avg_score: 15.5, best_score: 15.69, epsilon: 0.1
#
# Game 421
# Episode: 420, score: 19.0, avg_score: 15.5, best_score: 15.69, epsilon: 0.1
#
# Game 422
# Episode: 421, score: 15.0, avg_score: 15.52, best_score: 15.69, epsilon: 0.1
#
# Game 423
# Episode: 422, score: 20.0, avg_score: 15.56, best_score: 15.69, epsilon: 0.1
#
# Game 424
# Episode: 423, score: 19.0, avg_score: 15.57, best_score: 15.69, epsilon: 0.1
#
# Game 425
# Episode: 424, score: 15.0, avg_score: 15.57, best_score: 15.69, epsilon: 0.1
#
# Game 426
# Episode: 425, score: 17.0, avg_score: 15.59, best_score: 15.69, epsilon: 0.1
#
# Game 427
# Episode: 426, score: 20.0, avg_score: 15.61, best_score: 15.69, epsilon: 0.1
#
# Game 428
# Episode: 427, score: 19.0, avg_score: 15.71, best_score: 15.69, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 429
# Episode: 428, score: 17.0, avg_score: 15.76, best_score: 15.71, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 430
# Episode: 429, score: 15.0, avg_score: 15.78, best_score: 15.76, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 431
# Episode: 430, score: 16.0, avg_score: 15.76, best_score: 15.78, epsilon: 0.1
#
# Game 432
# Episode: 431, score: 10.0, avg_score: 15.67, best_score: 15.78, epsilon: 0.1
#
# Game 433
# Episode: 432, score: 13.0, avg_score: 15.61, best_score: 15.78, epsilon: 0.1
#
# Game 434
# Episode: 433, score: 20.0, avg_score: 15.7, best_score: 15.78, epsilon: 0.1
#
# Game 435
# Episode: 434, score: 16.0, avg_score: 15.77, best_score: 15.78, epsilon: 0.1
#
# Game 436
# Episode: 435, score: 15.0, avg_score: 15.79, best_score: 15.78, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 437
# Episode: 436, score: 16.0, avg_score: 15.8, best_score: 15.79, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 438
# Episode: 437, score: 21.0, avg_score: 15.81, best_score: 15.8, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 439
# Episode: 438, score: 13.0, avg_score: 15.83, best_score: 15.81, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 440
# Episode: 439, score: 12.0, avg_score: 15.78, best_score: 15.83, epsilon: 0.1
#
# Game 441
# Episode: 440, score: 17.0, avg_score: 15.8, best_score: 15.83, epsilon: 0.1
#
# Game 442
# Episode: 441, score: 17.0, avg_score: 15.81, best_score: 15.83, epsilon: 0.1
#
# Game 443
# Episode: 442, score: 18.0, avg_score: 15.87, best_score: 15.83, epsilon: 0.1
# ... saving checkpoint ...
# ... saving checkpoint ...
#
# Game 444
# Episode: 443, score: 16.0, avg_score: 15.84, best_score: 15.87, epsilon: 0.1
#
# Game 445
# Episode: 444, score: 7.0, avg_score: 15.78, best_score: 15.87, epsilon: 0.1
#
# Game 446
# Episode: 445, score: 10.0, avg_score: 15.71, best_score: 15.87, epsilon: 0.1
#
# Game 447
# Episode: 446, score: 18.0, avg_score: 15.7, best_score: 15.87, epsilon: 0.1
#
# Game 448
# Episode: 447, score: 17.0, avg_score: 15.69, best_score: 15.87, epsilon: 0.1
#
# Game 449
# Episode: 448, score: 17.0, avg_score: 15.67, best_score: 15.87, epsilon: 0.1
#
# Game 450
# Episode: 449, score: 16.0, avg_score: 15.66, best_score: 15.87, epsilon: 0.1
#
# Game 451
# Episode: 450, score: 5.0, avg_score: 15.62, best_score: 15.87, epsilon: 0.1
#
# Game 452
# Episode: 451, score: 15.0, avg_score: 15.64, best_score: 15.87, epsilon: 0.1
#
# Game 453
# Episode: 452, score: 18.0, avg_score: 15.67, best_score: 15.87, epsilon: 0.1
#
# Game 454
# Episode: 453, score: 19.0, avg_score: 15.68, best_score: 15.87, epsilon: 0.1
#
# Game 455
# Episode: 454, score: 13.0, avg_score: 15.6, best_score: 15.87, epsilon: 0.1
#
# Game 456
# Episode: 455, score: 18.0, avg_score: 15.65, best_score: 15.87, epsilon: 0.1
#
# Game 457
# Episode: 456, score: 17.0, avg_score: 15.65, best_score: 15.87, epsilon: 0.1
#
# Game 458
# Episode: 457, score: 10.0, avg_score: 15.59, best_score: 15.87, epsilon: 0.1
#
# Game 459
# Episode: 458, score: 13.0, avg_score: 15.54, best_score: 15.87, epsilon: 0.1
#
# Game 460
# Episode: 459, score: 13.0, avg_score: 15.54, best_score: 15.87, epsilon: 0.1
#
# Game 461
# Episode: 460, score: 17.0, avg_score: 15.55, best_score: 15.87, epsilon: 0.1
#
# Game 462
# Episode: 461, score: 19.0, avg_score: 15.65, best_score: 15.87, epsilon: 0.1
#
# Game 463
# Episode: 462, score: 18.0, avg_score: 15.64, best_score: 15.87, epsilon: 0.1
#
# Game 464
# Episode: 463, score: 15.0, avg_score: 15.6, best_score: 15.87, epsilon: 0.1
#
# Game 465
# Episode: 464, score: 11.0, avg_score: 15.54, best_score: 15.87, epsilon: 0.1
#
# Game 466
# Episode: 465, score: 16.0, avg_score: 15.52, best_score: 15.87, epsilon: 0.1
#
# Game 467
# Episode: 466, score: 13.0, avg_score: 15.52, best_score: 15.87, epsilon: 0.1
#
# Game 468
# Episode: 467, score: 15.0, avg_score: 15.5, best_score: 15.87, epsilon: 0.1
#
# Game 469
# Episode: 468, score: 15.0, avg_score: 15.54, best_score: 15.87, epsilon: 0.1
#
# Game 470
# Episode: 469, score: 16.0, avg_score: 15.53, best_score: 15.87, epsilon: 0.1
#
# Game 471
# Episode: 470, score: 16.0, avg_score: 15.49, best_score: 15.87, epsilon: 0.1
#
# Game 472
# Episode: 471, score: 19.0, avg_score: 15.55, best_score: 15.87, epsilon: 0.1
#
# Game 473
# Episode: 472, score: 17.0, avg_score: 15.55, best_score: 15.87, epsilon: 0.1
#
# Game 474
# Episode: 473, score: 17.0, avg_score: 15.66, best_score: 15.87, epsilon: 0.1
#
# Game 475
# Episode: 474, score: 15.0, avg_score: 15.62, best_score: 15.87, epsilon: 0.1
#
# Game 476
# Episode: 475, score: 18.0, avg_score: 15.64, best_score: 15.87, epsilon: 0.1
#
# Game 477
# Episode: 476, score: 17.0, avg_score: 15.65, best_score: 15.87, epsilon: 0.1
#
# Game 478
# Episode: 477, score: 18.0, avg_score: 15.7, best_score: 15.87, epsilon: 0.1
#
# Game 479
# Episode: 478, score: 13.0, avg_score: 15.67, best_score: 15.87, epsilon: 0.1
#
# Game 480
# Episode: 479, score: 15.0, avg_score: 15.66, best_score: 15.87, epsilon: 0.1
#
# Game 481
# Episode: 480, score: 8.0, avg_score: 15.62, best_score: 15.87, epsilon: 0.1
#
# Game 482
# Episode: 481, score: 17.0, avg_score: 15.64, best_score: 15.87, epsilon: 0.1
#
# Game 483
# Episode: 482, score: 12.0, avg_score: 15.58, best_score: 15.87, epsilon: 0.1
#
# Game 484
# Episode: 483, score: 16.0, avg_score: 15.57, best_score: 15.87, epsilon: 0.1
#
# Game 485
# Episode: 484, score: 19.0, avg_score: 15.59, best_score: 15.87, epsilon: 0.1
#
# Game 486
# Episode: 485, score: 18.0, avg_score: 15.61, best_score: 15.87, epsilon: 0.1
#
# Game 487
# Episode: 486, score: 16.0, avg_score: 15.61, best_score: 15.87, epsilon: 0.1
#
# Game 488
# Episode: 487, score: 15.0, avg_score: 15.64, best_score: 15.87, epsilon: 0.1
#
# Game 489
# Episode: 488, score: 12.0, avg_score: 15.58, best_score: 15.87, epsilon: 0.1
#
# Game 490
# Episode: 489, score: 15.0, avg_score: 15.54, best_score: 15.87, epsilon: 0.1
#
# Game 491
# Episode: 490, score: 18.0, avg_score: 15.54, best_score: 15.87, epsilon: 0.1
#
# Game 492
# Episode: 491, score: 20.0, avg_score: 15.56, best_score: 15.87, epsilon: 0.1
#
# Game 493
# Episode: 492, score: 13.0, avg_score: 15.52, best_score: 15.87, epsilon: 0.1
#
# Game 494
# Episode: 493, score: 20.0, avg_score: 15.6, best_score: 15.87, epsilon: 0.1
#
# Game 495
# Episode: 494, score: 18.0, avg_score: 15.59, best_score: 15.87, epsilon: 0.1
#
# Game 496
# Episode: 495, score: 11.0, avg_score: 15.55, best_score: 15.87, epsilon: 0.1
#
# Game 497
# Episode: 496, score: 19.0, avg_score: 15.56, best_score: 15.87, epsilon: 0.1
#
# Game 498
# Episode: 497, score: 14.0, avg_score: 15.53, best_score: 15.87, epsilon: 0.1
#
# Game 499
# Episode: 498, score: 17.0, avg_score: 15.59, best_score: 15.87, epsilon: 0.1
#
# Game 500
# Episode: 499, score: 16.0, avg_score: 15.64, best_score: 15.87, epsilon: 0.1

# %%
import pandas as pd
df = pd.DataFrame(
    {
        'steps_array': steps_array,
        'scores': scores,
        'eps_history': eps_history
    }
)

df
# Out:
#      steps_array  scores  eps_history
# 0           1056   -19.0      0.98975
# 1           1973   -20.0      0.98058
# 2           2970   -19.0      0.97061
# 3           3873   -21.0      0.96158
# 4           4729   -20.0      0.95302
# ..           ...     ...          ...
# 495      1057646    11.0      0.10000
# 496      1059442    19.0      0.10000
# 497      1061694    14.0      0.10000
# 498      1064107    17.0      0.10000
# 499      1066056    16.0      0.10000
#
# [500 rows x 3 columns]

# %%
df.to_csv('Atari_DQL_results.csv')
from google.colab import files
files.download('Atari_DQL_results.csv')
